# %% [markdown]
# ## Indeed와 StackoverFlow에서 원하는 채용공고 데이터 수집하기

# %%
from indeed_upgrade import get_jobs as get_indeed_jobs
from so_upgade import get_jobs as get_so_jobs
import requests
from save import save_to_file
import pandas as pd

# %% [markdown]
# ## Indeed 사이트에서 원하는 단어를 검색했을 때 데이터(직무, 회사, 위치, 구인링크) 출력

# %%
indeed_jobs = get_indeed_jobs('ruby')
# 파라미터에 원하는 단어 ex)ruby 검색
# Out:
# Scrapping Indeed page 0
# Scrapping Indeed page 1

# %% [markdown]
# ## StackoverFlow 사이트에서 Python 검색했을 시의 데이터(직무, 회사, 위치, 구인링크) 출력

# %%
so_jobs =get_so_jobs('ruby')
# 파라미터에 원하는 단어 ex)ruby 검색
# Out:
# Scrapping SO page 0
# Scrapping SO page 1
# Scrapping SO page 2
# Scrapping SO page 3
# Scrapping SO page 4
# Scrapping SO page 5
# Scrapping SO page 6
# Scrapping SO page 7
# Scrapping SO page 8
# Scrapping SO page 9
# Scrapping SO page 10
# Scrapping SO page 11
# Scrapping SO page 12

# %% [markdown]
# ### 두사이트에서 추출한 데이터 병합

# %%
jobs = so_jobs + indeed_jobs

# %%
jobs
# Out:
# [{'title': 'Software Engineering',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Wilmington, DE',
#   'link': 'https://stackoverflow.com/jobs/487157'},
#  {'title': 'Full Stack Engineer - Remote, USA ONLY',
#   'company': 'SocialChorus',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/371379'},
#  {'title': 'Software Engineer (Backend) - NYC/LA',
#   'company': 'Gravity Technologies',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/194557'},
#  {'title': 'Sr. Software Engineer - Ruby - Telehealth / Telemedicine',
#   'company': 'VisuWell',
#   'location': 'Nashville, TN',
#   'link': 'https://stackoverflow.com/jobs/487286'},
#  {'title': 'Software Engineer Ruby/Elixir for Internet of Things (f/m/d)',
#   'company': 'sonnen GmbH',
#   'location': 'Berlin, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/487278'},
#  {'title': 'Experienced Ruby on Rails Developer',
#   'company': 'SimplePay',
#   'location': 'Cape Town, South Africa',
#   'link': 'https://stackoverflow.com/jobs/450851'},
#  {'title': 'Software Developer Apprenticeship - Level 4',
#   'company': 'Immersive Labs',
#   'location': 'Bristol, UK',
#   'link': 'https://stackoverflow.com/jobs/487078'},
#  {'title': 'Software Engineer, Backend',
#   'company': 'SmartNews',
#   'location': 'Shibuya City, Japan',
#   'link': 'https://stackoverflow.com/jobs/208334'},
#  {'title': 'Sr. Product Security Engineer, Infrastructure & Security',
#   'company': 'Chan Zuckerberg Initiative',
#   'location': 'Redwood City, CA',
#   'link': 'https://stackoverflow.com/jobs/450614'},
#  {'title': 'Site Reliability Engineer',
#   'company': 'Zattoo',
#   'location': 'Berlin, Germany',
#   'link': 'https://stackoverflow.com/jobs/472441'},
#  {'title': 'Full Stack Developer - Ruby / React',
#   'company': 'Forward Financing',
#   'location': 'Boston, MA',
#   'link': 'https://stackoverflow.com/jobs/472420'},
#  {'title': 'Senior Software Developer, Application Security (Remote Option)',
#   'company': 'Clio',
#   'location': 'Burnaby, BC, Canada',
#   'link': 'https://stackoverflow.com/jobs/483219'},
#  {'title': 'Ruby Backend Developer (m/f/d) // Insurtech',
#   'company': 'GetSafe GmbH',
#   'location': 'Heidelberg, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/425436'},
#  {'title': '(100% Remote) Senior Ruby on Rails Engineer at Client Portal Team in Toptal.',
#   'company': 'Toptal',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/411472'},
#  {'title': 'Senior DevOps Engineer - Digital Utilities (m/w/d)',
#   'company': 'sonnen GmbH',
#   'location': 'Berlin, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/472375'},
#  {'title': 'Backend developer',
#   'company': 'VIKTOR',
#   'location': 'Rotterdam, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/472215'},
#  {'title': 'Senior Full Stack Engineer',
#   'company': 'UrbanFootprint, Inc.',
#   'location': 'Berkeley, CA',
#   'link': 'https://stackoverflow.com/jobs/486612'},
#  {'title': 'FullStack Developer',
#   'company': 'Envato Mexico',
#   'location': 'Guadalajara, Mexico',
#   'link': 'https://stackoverflow.com/jobs/414277'},
#  {'title': 'Backend Developer',
#   'company': 'Envato Mexico',
#   'location': 'Guadalajara, Mexico',
#   'link': 'https://stackoverflow.com/jobs/414275'},
#  {'title': 'Senior Observability Engineer - Disruptive $multi-billion SaaS Leader, York',
#   'company': 'Anaplan',
#   'location': 'York, UK',
#   'link': 'https://stackoverflow.com/jobs/414272'},
#  {'title': 'Senior Technical Product Manager (m/f/div) for PAIR Finance',
#   'company': 'PAIR Finance GmbH',
#   'location': 'Berlin, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/346301'},
#  {'title': '(Senior) DevOps and IT Operations Engineer (m/w/d)',
#   'company': 'ITS Berlin GmbH',
#   'location': 'Berlin, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/472009'},
#  {'title': 'Senior Software Engineer - Backend',
#   'company': 'Paddl Co Pty Ltd',
#   'location': 'Melbourne, Australia',
#   'link': 'https://stackoverflow.com/jobs/437339'},
#  {'title': 'Site Reliability Engineer',
#   'company': 'Wikimedia Foundation, Inc.',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/471812'},
#  {'title': 'Senior Software Engineer, Ruby (Billing Team)',
#   'company': 'BigCommerce',
#   'location': 'Austin, TX',
#   'link': 'https://stackoverflow.com/jobs/435600'},
#  {'title': 'Senior UI Engineer',
#   'company': 'OneMain Financial',
#   'location': 'Chicago, IL',
#   'link': 'https://stackoverflow.com/jobs/486422'},
#  {'title': 'Full-Stack Web Developer (U.S. Remote or Chicago Office)',
#   'company': 'Alpine Home Air Products',
#   'location': 'Chicago, IL',
#   'link': 'https://stackoverflow.com/jobs/486594'},
#  {'title': 'Senior Software Engineer, Curriculum, Education',
#   'company': 'Chan Zuckerberg Initiative',
#   'location': 'Redwood City, CA',
#   'link': 'https://stackoverflow.com/jobs/437134'},
#  {'title': 'Senior Software Engineer',
#   'company': 'Contrast Security',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/486421'},
#  {'title': 'Cloud Infrastructure Engineer',
#   'company': 'UKG (Ultimate Kronos Group)',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/486405'},
#  {'title': 'Documentation & Deployment Engineer (DevTech, PowerVR Software Graphics)',
#   'company': 'Imagination Technologies',
#   'location': 'Kings Langley, UK',
#   'link': 'https://stackoverflow.com/jobs/471601'},
#  {'title': 'Senior Reliablity Engineer (Production)',
#   'company': 'Mastercard',
#   'location': 'Rickmansworth, UK',
#   'link': 'https://stackoverflow.com/jobs/424556'},
#  {'title': 'Test Automation Engineer',
#   'company': 'iubenda',
#   'location': 'Bologna, Italy',
#   'link': 'https://stackoverflow.com/jobs/486378'},
#  {'title': 'Software Engineer / DevOps',
#   'company': 'iubenda',
#   'location': 'Milan, Italy',
#   'link': 'https://stackoverflow.com/jobs/486377'},
#  {'title': 'Senior Ruby on Rails Developer',
#   'company': 'Eezy Inc.',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/486371'},
#  {'title': 'Senior Ruby + React Engineer',
#   'company': 'Hubstaff',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/486370'},
#  {'title': 'Senior Software Engineer (Infrastructure)',
#   'company': 'On',
#   'location': 'Berlin, Germany',
#   'link': 'https://stackoverflow.com/jobs/486363'},
#  {'title': 'Software Developer in Test',
#   'company': 'Driver & Vehicle Standards Agency - DVSA',
#   'location': 'Nottingham, UK',
#   'link': 'https://stackoverflow.com/jobs/486209'},
#  {'title': 'VP Engineering',
#   'company': 'Shipup',
#   'location': 'Paris, France',
#   'link': 'https://stackoverflow.com/jobs/441426'},
#  {'title': 'SENIOR RUBY DEVELOPER / BACKEND (W/F/D)',
#   'company': 'metoda GmbH',
#   'location': 'München, Germany',
#   'link': 'https://stackoverflow.com/jobs/486206'},
#  {'title': 'Senior Ruby Developer',
#   'company': 'Red Ant',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/486192'},
#  {'title': 'Staff Engineer, Monetization',
#   'company': 'MasterClass',
#   'location': 'San Francisco, CA',
#   'link': 'https://stackoverflow.com/jobs/486186'},
#  {'title': 'Senior Backend Engineer',
#   'company': 'Knotch',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/471358'},
#  {'title': 'Python Software Engineer',
#   'company': 'Captivation Software',
#   'location': 'Fort Meade, MD',
#   'link': 'https://stackoverflow.com/jobs/449506'},
#  {'title': 'Full Stack Developer',
#   'company': 'Applied Research Associates',
#   'location': 'Raleigh, NC',
#   'link': 'https://stackoverflow.com/jobs/436178'},
#  {'title': 'Software Engineer',
#   'company': 'Skylight',
#   'location': 'Sarasota, FL',
#   'link': 'https://stackoverflow.com/jobs/485950'},
#  {'title': 'DevOps Engineer',
#   'company': 'Skylight',
#   'location': 'Sarasota, FL',
#   'link': 'https://stackoverflow.com/jobs/485948'},
#  {'title': 'Senior/Lead Software Engineer',
#   'company': 'CV Partner',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/471140'},
#  {'title': 'Senior DevOps Engineer',
#   'company': 'emerchantpay',
#   'location': 'Sofia, Bulgaria',
#   'link': 'https://stackoverflow.com/jobs/366030'},
#  {'title': 'Site Reliability Engineer (Remote)',
#   'company': 'Booming Games Malta Ltd.',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/485107'},
#  {'title': 'Software Engineer C/C++ Mobile Applications',
#   'company': 'KI group GmbH',
#   'location': 'Stuttgart, Germany',
#   'link': 'https://stackoverflow.com/jobs/485050'},
#  {'title': 'Computer Scientist / IT Specialist as developer (m/f) Ruby on Rails',
#   'company': 'Hüttig & Rompf AG',
#   'location': 'Frankfurt am Main, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/143409'},
#  {'title': 'Senior Backend Developer - ruby/rails',
#   'company': 'emerchantpay',
#   'location': 'Sofia, Bulgaria',
#   'link': 'https://stackoverflow.com/jobs/365945'},
#  {'title': 'Software Engineer in Test (remote)',
#   'company': 'Web Summit',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/427673'},
#  {'title': 'DevOps Engeneer (m/w/d)',
#   'company': 'RheinEnergie AG',
#   'location': 'Köln, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/485764'},
#  {'title': 'Full Stack Engineer - Rails/React - Remote',
#   'company': 'Brightline',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/470809'},
#  {'title': 'Ruby On Rails Developer',
#   'company': 'BairesDev LLC',
#   'location': 'San Francisco, CA',
#   'link': 'https://stackoverflow.com/jobs/485562'},
#  {'title': 'Junior Backend Engineer (f/m/d)',
#   'company': 'Personio',
#   'location': 'Madrid, Spain',
#   'link': 'https://stackoverflow.com/jobs/448561'},
#  {'title': 'Sr. Security Engineer',
#   'company': "Domino's Pizza",
#   'location': 'Ann Arbor, MI',
#   'link': 'https://stackoverflow.com/jobs/485500'},
#  {'title': 'Principal Engineer at the leading data-driven travel advertising platform!',
#   'company': 'travel audience GmbH',
#   'location': 'Berlin, Germany',
#   'link': 'https://stackoverflow.com/jobs/282357'},
#  {'title': 'Engineering Manager - Join our growing team of 40+ software engineers',
#   'company': 'Tails.com',
#   'location': 'Richmond, UK',
#   'link': 'https://stackoverflow.com/jobs/391983'},
#  {'title': 'Site Reliability Engineer - Consumer & Community Bank | ICTO Digital Technology',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'link': 'https://stackoverflow.com/jobs/485469'},
#  {'title': 'Applications     Support',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Columbus, OH',
#   'link': 'https://stackoverflow.com/jobs/485464'},
#  {'title': 'Java Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Wilmington, DE',
#   'link': 'https://stackoverflow.com/jobs/485274'},
#  {'title': 'Senior Software Engineer Rails/Elm/React',
#   'company': 'HubTran Inc.',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/410103'},
#  {'title': 'Team lead .NET',
#   'company': 'Lime',
#   'location': 'Lund, Sweden',
#   'link': 'https://stackoverflow.com/jobs/401811'},
#  {'title': 'Backend .NET Developer',
#   'company': 'Tipser AB',
#   'location': 'Wrocław, Poland',
#   'link': 'https://stackoverflow.com/jobs/458623'},
#  {'title': 'DevOps Engineer',
#   'company': 'Tipser AB',
#   'location': 'Wrocław, Poland',
#   'link': 'https://stackoverflow.com/jobs/458622'},
#  {'title': 'QA Engineer',
#   'company': 'Digidentity',
#   'location': 'Den Haag, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/409503'},
#  {'title': 'DevOps Projektingenieur (m/w/d)',
#   'company': 'SVA System Vertrieb Alexander GmbH',
#   'location': 'Wiesbaden, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/374378'},
#  {'title': 'DevOps Engineer / System Administrator – Operational Services (m/w/d)',
#   'company': 'SVA System Vertrieb Alexander GmbH',
#   'location': 'Schwerte, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/374377'},
#  {'title': 'Senior Rails Developer',
#   'company': 'Marketcircle',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/470409'},
#  {'title': 'Senior Backend Software Developer ioki (f/m/d)',
#   'company': 'ioki GmbH',
#   'location': 'Frankfurt am Main, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/465122'},
#  {'title': 'Software Engineer, Site Reliability Engineering (SRE)',
#   'company': 'SmartNews',
#   'location': 'Shibuya City, Japan',
#   'link': 'https://stackoverflow.com/jobs/448299'},
#  {'title': 'Backend Software Engineer / Ingénieur développement logiciel Backend',
#   'company': 'BuyCo',
#   'location': 'Marseille, France',
#   'link': 'https://stackoverflow.com/jobs/435719'},
#  {'title': 'Ruby on Rails Developer',
#   'company': 'KiteString Technical Services, formerly LJSA.',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/469977'},
#  {'title': 'Engineering Manager',
#   'company': 'Ritual',
#   'location': 'Culver City, CA',
#   'link': 'https://stackoverflow.com/jobs/484848'},
#  {'title': 'Senior Site Reliability Engineer (Remote)',
#   'company': 'Hypothesis.is',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/458450'},
#  {'title': 'Senior Software Engineer, Back-End (Ruby/Rails)',
#   'company': 'Ritual',
#   'location': 'Culver City, CA',
#   'link': 'https://stackoverflow.com/jobs/204713'},
#  {'title': 'Senior Site Reliability Engineer (Distributed Storage)',
#   'company': 'Wikimedia Foundation, Inc.',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/455953'},
#  {'title': 'Senior Backend Engineer (Ruby on Rails)',
#   'company': 'Files.com',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/282423'},
#  {'title': 'Senior Operation Engineer (DevOps)',
#   'company': 'Hopjump',
#   'location': 'Cambridge, MA',
#   'link': 'https://stackoverflow.com/jobs/447982'},
#  {'title': 'Mobile Applications Developer',
#   'company': 'Market America / Shop.com',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/447980'},
#  {'title': 'Senior Software Engineer',
#   'company': 'tastyworks',
#   'location': 'Chicago, IL',
#   'link': 'https://stackoverflow.com/jobs/386497'},
#  {'title': 'Application Security Developer',
#   'company': 'New Context Services',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/458263'},
#  {'title': 'Senior Software Engineer',
#   'company': 'Wyzant',
#   'location': 'Chicago, IL',
#   'link': 'https://stackoverflow.com/jobs/484644'},
#  {'title': 'Experienced Backend Developer',
#   'company': 'Bublup, Inc',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/482420'},
#  {'title': 'Product Security Engineer (All Levels)',
#   'company': 'Salesforce',
#   'location': 'San Francisco, CA',
#   'link': 'https://stackoverflow.com/jobs/339183'},
#  {'title': 'Software Developer',
#   'company': 'Collage',
#   'location': 'Toronto, ON, Canada',
#   'link': 'https://stackoverflow.com/jobs/484604'},
#  {'title': 'Product Developer (Backend/Go)',
#   'company': 'Appvia',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/484437'},
#  {'title': 'Senior Back-end / Ruby on Rails Developer',
#   'company': 'iubenda',
#   'location': 'Milan, Italy',
#   'link': 'https://stackoverflow.com/jobs/484432'},
#  {'title': 'Mobile Quality Engineer',
#   'company': 'Revance',
#   'location': 'Pleasanton, CA',
#   'link': 'https://stackoverflow.com/jobs/458098'},
#  {'title': 'DevOps Engineer',
#   'company': 'Ultra Tendency',
#   'location': 'Berlin, Germany',
#   'link': 'https://stackoverflow.com/jobs/469788'},
#  {'title': 'Software Engineer - Integrations team',
#   'company': 'Tipser AB',
#   'location': 'Barcelona, Spain',
#   'link': 'https://stackoverflow.com/jobs/457941'},
#  {'title': 'Senior RoR, Product Engineer London or remote (within EU time-zone)',
#   'company': 'Cleo AI',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/420634'},
#  {'title': 'Ruby on Rails Software Engineer',
#   'company': 'Leadfeeder',
#   'location': 'Helsinki, Finland',
#   'link': 'https://stackoverflow.com/jobs/469533'},
#  {'title': 'Software Architects (Multiple Locations)',
#   'company': 'Salesforce',
#   'location': 'Seattle, WA',
#   'link': 'https://stackoverflow.com/jobs/364250'},
#  {'title': 'Software Architects (Multiple Locations)',
#   'company': 'Salesforce',
#   'location': 'San Francisco, CA',
#   'link': 'https://stackoverflow.com/jobs/364249'},
#  {'title': 'DevOps Engineers All Levels (Senior/Lead/Principal) (Multiple Locations)',
#   'company': 'Salesforce',
#   'location': 'Boston, MA',
#   'link': 'https://stackoverflow.com/jobs/364241'},
#  {'title': 'DevOps Engineers All Levels (Senior/Lead/Principal) (Multiple Locations)',
#   'company': 'Salesforce',
#   'location': 'Seattle, WA',
#   'link': 'https://stackoverflow.com/jobs/364240'},
#  {'title': 'Senior Solutions Architect, Game Industry',
#   'company': 'Amazon Web Services',
#   'location': 'Tokyo, Japan',
#   'link': 'https://stackoverflow.com/jobs/390527'},
#  {'title': 'DevOps Engineers All Levels (Senior/Lead/Principal) (Multiple Locations)',
#   'company': 'Salesforce',
#   'location': 'San Francisco, CA',
#   'link': 'https://stackoverflow.com/jobs/364239'},
#  {'title': 'Full-Stack Software Engineer (Senior, Lead, Principal) – Application Development',
#   'company': 'Salesforce',
#   'location': 'Louisville, CO',
#   'link': 'https://stackoverflow.com/jobs/364228'},
#  {'title': 'Full-Stack Software Engineer (Senior, Lead, Principal) – Application Development',
#   'company': 'Salesforce',
#   'location': 'Indianapolis, IN',
#   'link': 'https://stackoverflow.com/jobs/364227'},
#  {'title': 'Full-Stack Software Engineer (Senior, Lead, Principal) – Application Development',
#   'company': 'Salesforce',
#   'location': 'Boston, MA',
#   'link': 'https://stackoverflow.com/jobs/364226'},
#  {'title': 'Full-Stack Software Engineer (Senior, Lead, Principal) – Application Development',
#   'company': 'Salesforce',
#   'location': 'Seattle, WA',
#   'link': 'https://stackoverflow.com/jobs/364225'},
#  {'title': 'Full-Stack Software Engineer (Senior, Lead, Principal) – Application Development',
#   'company': 'Salesforce',
#   'location': 'San Francisco, CA',
#   'link': 'https://stackoverflow.com/jobs/364221'},
#  {'title': 'Principal/ Lead/ Sr. Platform/ Back-end Eng',
#   'company': 'Salesforce',
#   'location': 'Boston, MA',
#   'link': 'https://stackoverflow.com/jobs/364215'},
#  {'title': 'Principal/ Lead/ Sr. Platform/ Back-end Eng',
#   'company': 'Salesforce',
#   'location': 'Indianapolis, IN',
#   'link': 'https://stackoverflow.com/jobs/364214'},
#  {'title': 'Principal/ Lead/ Sr. Platform/ Back-end Eng',
#   'company': 'Salesforce',
#   'location': 'Seattle, WA',
#   'link': 'https://stackoverflow.com/jobs/364213'},
#  {'title': 'Principal/ Lead/ Sr. Platform/ Back-end Eng',
#   'company': 'Salesforce',
#   'location': 'San Francisco, CA',
#   'link': 'https://stackoverflow.com/jobs/364212'},
#  {'title': 'Software Engineer All Levels (Senior/Lead/Principal)',
#   'company': 'Salesforce',
#   'location': 'Indianapolis, IN',
#   'link': 'https://stackoverflow.com/jobs/364210'},
#  {'title': 'Software Engineer All Levels (Senior/Lead/Principal)',
#   'company': 'Salesforce',
#   'location': 'Boston, MA',
#   'link': 'https://stackoverflow.com/jobs/364209'},
#  {'title': 'Software Engineer All Levels (Senior/Lead/Principal)',
#   'company': 'Salesforce',
#   'location': 'Seattle, WA',
#   'link': 'https://stackoverflow.com/jobs/364208'},
#  {'title': 'Software Engineer All Levels (Senior/Lead/Principal)',
#   'company': 'Salesforce',
#   'location': 'San Francisco, CA',
#   'link': 'https://stackoverflow.com/jobs/364207'},
#  {'title': 'Sr/Lead Backend Engineer - (US Citizen)',
#   'company': 'Salesforce',
#   'location': 'Seattle, WA',
#   'link': 'https://stackoverflow.com/jobs/364186'},
#  {'title': 'Software Engineer/Software Developer Wanted',
#   'company': 'Nova Dynamics',
#   'location': 'Philomath, OR',
#   'link': 'https://stackoverflow.com/jobs/392809'},
#  {'title': 'Sr/Lead Backend Engineer - Security',
#   'company': 'Salesforce',
#   'location': 'San Francisco, CA',
#   'link': 'https://stackoverflow.com/jobs/364145'},
#  {'title': 'Senior Fullstack Software Developer for Interactive Healthcare SaaS Platform',
#   'company': 'The Jellyvision Lab Inc.',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/457661'},
#  {'title': 'Backend Developer',
#   'company': 'Hemnet',
#   'location': 'Stockholm, Sweden',
#   'link': 'https://stackoverflow.com/jobs/457660'},
#  {'title': 'Junior System Engineer Linux (m/w), 80-100 %',
#   'company': 'CONCORDIA',
#   'location': 'Luzern, Schweiz',
#   'link': 'https://stackoverflow.com/jobs/457654'},
#  {'title': 'Senior Software Engineer, Core Infrastructure',
#   'company': 'Chan Zuckerberg Initiative',
#   'location': 'Redwood City, CA',
#   'link': 'https://stackoverflow.com/jobs/483720'},
#  {'title': 'Senior Software Development Engineer - Web and International QA Team',
#   'company': 'Audible',
#   'location': 'Newark, NJ',
#   'link': 'https://stackoverflow.com/jobs/438809'},
#  {'title': 'Network Engineer II',
#   'company': 'Audible',
#   'location': 'Newark, NJ',
#   'link': 'https://stackoverflow.com/jobs/377999'},
#  {'title': 'Principal Software Development Engineer, Backend',
#   'company': 'ReCharge Payments',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/463336'},
#  {'title': 'WANTED: Rails Developer - To solve a challenging problem with a senior team!',
#   'company': 'Disputify Pty Ltd',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/463327'},
#  {'title': 'Senior Software Development Engineer, Platform API',
#   'company': 'ReCharge Payments',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/469142'},
#  {'title': 'Senior Full Stack Developer – EMR Applications - US only',
#   'company': 'ClearCost Health',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/483506'},
#  {'title': 'Sr. Platform Developer to Innovate on the Future of Commerce',
#   'company': 'Sionic Mobile Corporation',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/482978'},
#  {'title': '(Senior) Systems Engineer im DevOps-Umfeld (m/w/d) in Stuttgart',
#   'company': 'jambit GmbH',
#   'location': 'Stuttgart, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/483477'},
#  {'title': 'Platform Engineer - Kubernetes Developer',
#   'company': 'QOMPLX, Inc.',
#   'location': 'McLean, VA',
#   'link': 'https://stackoverflow.com/jobs/433906'},
#  {'title': '(Senior) Systems Engineer im DevOps-Umfeld (m/w/d)',
#   'company': 'jambit GmbH',
#   'location': 'Leipzig, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/483474'},
#  {'title': 'Software Developer',
#   'company': 'Extreme Engineering Solutions (X-ES)',
#   'location': 'Verona, WI',
#   'link': 'https://stackoverflow.com/jobs/468946'},
#  {'title': 'Software Engineer - Clearance Required - Multidisciplinary',
#   'company': 'BrainGu',
#   'location': 'Chantilly, VA',
#   'link': 'https://stackoverflow.com/jobs/267449'},
#  {'title': 'Senior Software Engineer - Ruby on Rails (NYC/Munich)',
#   'company': 'Kaia Health Software GmbH',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/457378'},
#  {'title': 'Senior Software Developer (Remote Option)',
#   'company': 'Clio',
#   'location': 'Toronto, ON, Canada',
#   'link': 'https://stackoverflow.com/jobs/483218'},
#  {'title': 'Senior Product Security Engineer, Infrastructure & Security',
#   'company': 'Chan Zuckerberg Initiative',
#   'location': 'Redwood City, CA',
#   'link': 'https://stackoverflow.com/jobs/446775'},
#  {'title': 'Lead Product Security Engineer, Infrastructure & Security',
#   'company': 'Chan Zuckerberg Initiative',
#   'location': 'Redwood City, CA',
#   'link': 'https://stackoverflow.com/jobs/446774'},
#  {'title': 'Software Engineer',
#   'company': 'Realtor.com',
#   'location': 'Richmond, BC, Canada',
#   'link': 'https://stackoverflow.com/jobs/482974'},
#  {'title': 'Senior Full Stack Engineer (Ruby on Rails)',
#   'company': 'Pledgeling Technologies',
#   'location': 'Los Angeles, CA',
#   'link': 'https://stackoverflow.com/jobs/482964'},
#  {'title': 'Senior Systems Engineer, Data Services',
#   'company': 'Olo',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/295293'},
#  {'title': 'Ruby Engineer',
#   'company': 'Bold Penguin',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/482945'},
#  {'title': 'Ruby Engineer',
#   'company': 'Bold Penguin',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/191831'},
#  {'title': 'QA Automation Engineer',
#   'company': 'ErisX',
#   'location': 'Chicago, IL',
#   'link': 'https://stackoverflow.com/jobs/482934'},
#  {'title': 'Build and Release Engineer',
#   'company': 'Flock Safety',
#   'location': 'Atlanta, GA',
#   'link': 'https://stackoverflow.com/jobs/482923'},
#  {'title': 'DevOps Engineer (AWS, Linux, k8s)',
#   'company': 'LHV SoftwareviaTopDev',
#   'location': 'Quận 10, Vietnam',
#   'link': 'https://stackoverflow.com/jobs/468282'},
#  {'title': 'Ruby on Rails Developer (f/m/div) in FinTech',
#   'company': 'PAIR Finance GmbH',
#   'location': 'Berlin, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/424974'},
#  {'title': 'Tech Lead Manager, Criminal Justice, Justice & Opportunity',
#   'company': 'Chan Zuckerberg Initiative',
#   'location': 'Redwood City, CA',
#   'link': 'https://stackoverflow.com/jobs/446369'},
#  {'title': 'Staff Software Engineer, Infrastructure, Education',
#   'company': 'Chan Zuckerberg Initiative',
#   'location': 'Redwood City, CA',
#   'link': 'https://stackoverflow.com/jobs/446365'},
#  {'title': 'Principal Site Reliability Engineer',
#   'company': 'Happy Money',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/482703'},
#  {'title': 'Software Engineering (IOS Developer)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/482226'},
#  {'title': 'Software Engineering - Rates Athena - VP',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Mumbai, India',
#   'link': 'https://stackoverflow.com/jobs/482498'},
#  {'title': 'Senior Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Redwood City, CA',
#   'link': 'https://stackoverflow.com/jobs/482492'},
#  {'title': 'Cloud Engineer - AWS',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/482487'},
#  {'title': 'Software Engineer',
#   'company': 'Trainual',
#   'location': 'Scottsdale, AZ',
#   'link': 'https://stackoverflow.com/jobs/446351'},
#  {'title': 'Computer Scientist - Development Programs - Entry/ Mid-Level',
#   'company': 'National Security Agency',
#   'location': 'Fort Meade, MD',
#   'link': 'https://stackoverflow.com/jobs/482446'},
#  {'title': 'Site Reliability Engineer (SRE)',
#   'company': 'Quadpay',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/415843'},
#  {'title': 'CTO',
#   'company': 'Visit.org, Inc.',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/482433'},
#  {'title': 'Distinguished Architect',
#   'company': 'Citizens Bank',
#   'location': 'Boston, MA',
#   'link': 'https://stackoverflow.com/jobs/482417'},
#  {'title': 'Senior Architect',
#   'company': 'Citizens Bank',
#   'location': 'Providence, RI',
#   'link': 'https://stackoverflow.com/jobs/482411'},
#  {'title': 'Senior Software Engineer - Cloud',
#   'company': 'Citizens Bank',
#   'location': 'Westwood, MA',
#   'link': 'https://stackoverflow.com/jobs/482401'},
#  {'title': 'Site Reliability Engineer- ArcGIS Online',
#   'company': 'Esri',
#   'location': 'Redlands, CA',
#   'link': 'https://stackoverflow.com/jobs/410786'},
#  {'title': 'QA Automation Engineer (m/f/x)',
#   'company': 'MEDWING GmbH',
#   'location': 'Berlin, Germany',
#   'link': 'https://stackoverflow.com/jobs/378225'},
#  {'title': 'Engineer CoC Datennetze WDM (m/w)',
#   'company': 'SBB AG',
#   'location': 'Ostermundigen, Schweiz',
#   'link': 'https://stackoverflow.com/jobs/482387'},
#  {'title': 'QA - Automation Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Chicago, IL',
#   'link': 'https://stackoverflow.com/jobs/482139'},
#  {'title': 'PHP Web Developer',
#   'company': 'Yaraku, Inc.',
#   'location': 'Shibuya City, Japan',
#   'link': 'https://stackoverflow.com/jobs/230517'},
#  {'title': 'Senior Front-end Engineer',
#   'company': 'UrbanFootprint, Inc.',
#   'location': 'Berkeley, CA',
#   'link': 'https://stackoverflow.com/jobs/482087'},
#  {'title': 'Software Engineer - Backend',
#   'company': 'ErisX',
#   'location': 'Chicago, IL',
#   'link': 'https://stackoverflow.com/jobs/482077'},
#  {'title': 'Ruby Developer',
#   'company': 'IntellumviaTechCXO',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/482074'},
#  {'title': 'Senior Frontend Engineer (ES8/React/Redux/Saga)',
#   'company': 'Files.com',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/241031'},
#  {'title': 'Technical Product Support Engineer (Remote)',
#   'company': 'Olive AI',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/410488'},
#  {'title': 'Rails Developer',
#   'company': 'Confluence',
#   'location': 'Cape Town, South Africa',
#   'link': 'https://stackoverflow.com/jobs/457014'},
#  {'title': 'Senior Mobile Developer (Android)',
#   'company': 'tastyworks',
#   'location': 'Chicago, IL',
#   'link': 'https://stackoverflow.com/jobs/386500'},
#  {'title': 'Angular/Ruby on Rails Developer (US or Canada)',
#   'company': 'BiTE interactive',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/481735'},
#  {'title': 'Ruby on Rails Developer (m/w/d) - Remote',
#   'company': 'evopark GmbH',
#   'location': 'Köln, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/432591'},
#  {'title': 'Ruby on Rails Developer',
#   'company': 'Catawiki',
#   'location': 'Amsterdam, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/481723'},
#  {'title': 'Software Engineer',
#   'company': 'High AlphaviaHigh Alpha Studio, LLC.',
#   'location': 'Indianapolis, IN',
#   'link': 'https://stackoverflow.com/jobs/481730'},
#  {'title': 'Lead Developer',
#   'company': 'Catawiki',
#   'location': 'Amsterdam, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/481722'},
#  {'title': 'DevOps Engineer',
#   'company': 'Derivco',
#   'location': 'Barcelona, Spain',
#   'link': 'https://stackoverflow.com/jobs/481719'},
#  {'title': 'Lead Quality Analyst',
#   'company': 'Scripbox',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/206760'},
#  {'title': 'Front End Designer/Developer',
#   'company': 'L2P Enterprise Ltd',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/432527'},
#  {'title': 'Fully Remote - Senior Full Stack Engineer - React & Node or Ruby - Teespring',
#   'company': 'TeespringviaSource Coders',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/481483'},
#  {'title': 'Mid or Sr. Software Engineer in Java',
#   'company': 'Brazen Technologies',
#   'location': 'Arlington, WA',
#   'link': 'https://stackoverflow.com/jobs/481215'},
#  {'title': 'DevOps Engineer',
#   'company': 'SIMON Markets',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/353202'},
#  {'title': 'Software Engineer, Ruby/Rails',
#   'company': 'Red Canary',
#   'location': 'Denver, CO',
#   'link': 'https://stackoverflow.com/jobs/481206'},
#  {'title': 'Senior Software Engineer, Rust/Go & Linux',
#   'company': 'Red Canary',
#   'location': 'Denver, CO',
#   'link': 'https://stackoverflow.com/jobs/481205'},
#  {'title': 'Senior Software Engineer, Ruby/Rails',
#   'company': 'Red Canary',
#   'location': 'Denver, CO',
#   'link': 'https://stackoverflow.com/jobs/481203'},
#  {'title': 'DevOps Engineer',
#   'company': 'BTI360',
#   'location': 'Ashburn, VA',
#   'link': 'https://stackoverflow.com/jobs/410142'},
#  {'title': 'Senior Ruby + React Engineer',
#   'company': 'Hubstaff',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/481186'},
#  {'title': 'Staff Software Engineer - Pricing at Root Insurance (a $6B valuation startup)',
#   'company': 'Root Insurance Company',
#   'location': 'Chicago, IL',
#   'link': 'https://stackoverflow.com/jobs/272924'},
#  {'title': 'Software Engineer II at Root Insurance (a $6B valuation startup)',
#   'company': 'Root Insurance Company',
#   'location': 'Columbus, OH',
#   'link': 'https://stackoverflow.com/jobs/282045'},
#  {'title': 'Senior Software Engineer at Root Insurance (a $6B valuation startup)',
#   'company': 'Root Insurance Company',
#   'location': 'Columbus, OH',
#   'link': 'https://stackoverflow.com/jobs/282042'},
#  {'title': 'React Staff Software Engineer at Root Insurance (a $6B valuation startup)',
#   'company': 'Root Insurance Company',
#   'location': 'Columbus, OH',
#   'link': 'https://stackoverflow.com/jobs/365535'},
#  {'title': 'Engineering Manager at Root Insurance (a $6B valuation startup)',
#   'company': 'Root Insurance Company',
#   'location': 'Columbus, OH',
#   'link': 'https://stackoverflow.com/jobs/251049'},
#  {'title': 'DevSecOps Engineer at Root Insurance (a $6B valuation startup)',
#   'company': 'Root Insurance Company',
#   'location': 'Chicago, IL',
#   'link': 'https://stackoverflow.com/jobs/456294'},
#  {'title': 'Product Security Engineer',
#   'company': 'SUSE',
#   'location': 'Sofia, Bulgaria',
#   'link': 'https://stackoverflow.com/jobs/445048'},
#  {'title': 'Site Reliability Engineer',
#   'company': 'Government Digital Service (GDS)',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/481147'},
#  {'title': 'Senior Fullstack Engineer (Remote)',
#   'company': 'Web Summit',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/417479'},
#  {'title': 'Senior Backend Engineer - Ruby on Rails - Freelance Remote (f/m/d)',
#   'company': 'Workpath GmbH',
#   'location': 'Madrid, Spain',
#   'link': 'https://stackoverflow.com/jobs/469777'},
#  {'title': 'Senior Full-Stack Engineer',
#   'company': 'Made Market, Inc.',
#   'location': 'Santa Monica, CA',
#   'link': 'https://stackoverflow.com/jobs/456324'},
#  {'title': 'Principal Backend Engineer - Rails',
#   'company': 'FortressIQ',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/431807'},
#  {'title': 'Senior Python Engineer',
#   'company': 'Tivix',
#   'location': 'Wrocław, Poland',
#   'link': 'https://stackoverflow.com/jobs/420641'},
#  {'title': 'SRE/Devops Engineer',
#   'company': 'Resultados Digitais',
#   'location': 'Florianópolis, Brazil',
#   'link': 'https://stackoverflow.com/jobs/467106'},
#  {'title': 'Full-Stack Software Engineer',
#   'company': 'Strata Oncology',
#   'location': 'Ann Arbor, MI',
#   'link': 'https://stackoverflow.com/jobs/371127'},
#  {'title': 'Full Stack Software Developer: Fast Growing eCommerce Start-up',
#   'company': 'GlamCorner',
#   'location': 'Sydney, Australia',
#   'link': 'https://stackoverflow.com/jobs/456231'},
#  {'title': 'Engineering Manager',
#   'company': 'Babbel (Lesson Nine GmbH)',
#   'location': 'Berlin, Germany',
#   'link': 'https://stackoverflow.com/jobs/456050'},
#  {'title': 'Full Stack Web Developer',
#   'company': 'SUSE',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/424946'},
#  {'title': 'Software Engineering Manager',
#   'company': 'YouGov',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/466410'},
#  {'title': 'Software Development Lead - Payments',
#   'company': 'Network Guard',
#   'location': 'Hong Kong',
#   'link': 'https://stackoverflow.com/jobs/466275'},
#  {'title': 'Server-side Software Developer',
#   'company': 'Network Guard',
#   'location': 'Hong Kong',
#   'link': 'https://stackoverflow.com/jobs/466273'},
#  {'title': 'Solutions Architect, Manager',
#   'company': 'Amazon Web Services',
#   'location': 'Tel Aviv-Yafo, Israel',
#   'link': 'https://stackoverflow.com/jobs/390122'},
#  {'title': 'Senior Ruby Web Developer',
#   'company': 'Cookpad Limited',
#   'location': 'Bristol, UK',
#   'link': 'https://stackoverflow.com/jobs/466227'},
#  {'title': 'Senior Site Reliability Engineer',
#   'company': 'Cookpad Limited',
#   'location': 'Bristol, UK',
#   'link': 'https://stackoverflow.com/jobs/466002'},
#  {'title': 'Softwareentwickler (d/m/w)* IT-Security',
#   'company': 'genua gmbh',
#   'location': 'Kirchheim bei München, Germany',
#   'link': 'https://stackoverflow.com/jobs/360716'},
#  {'title': 'DevOps Consultant for Cologne, Düsseldorf, Frankfurt, Munich, Berlin',
#   'company': 'Eficode Germany',
#   'location': 'Düsseldorf, Germany',
#   'link': 'https://stackoverflow.com/jobs/360714'},
#  {'title': 'DevOps Consultant',
#   'company': 'Eficode the Netherlands',
#   'location': 'Amsterdam, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/360712'},
#  {'title': 'Ruby on Rails Platform Team-Lead',
#   'company': 'Farmy AG',
#   'location': 'Barcelona, Spanien',
#   'link': 'https://stackoverflow.com/jobs/465970'},
#  {'title': 'Senior Product Security Engineer',
#   'company': 'News UK',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/455733'},
#  {'title': 'Backend Engineer',
#   'company': 'Joint Academy',
#   'location': 'Malmö, Sweden',
#   'link': 'https://stackoverflow.com/jobs/465934'},
#  {'title': 'Front-End Web Software Engineer (Mid-Senior)',
#   'company': 'Agworld',
#   'location': 'West Leederville, Australia',
#   'link': 'https://stackoverflow.com/jobs/455178'},
#  {'title': 'Infrastructure Engineer II',
#   'company': 'BigCommerce',
#   'location': 'Austin, TX',
#   'link': 'https://stackoverflow.com/jobs/465705'},
#  {'title': 'Infrastructure Engineer II',
#   'company': 'BigCommerce',
#   'location': 'San Francisco, CA',
#   'link': 'https://stackoverflow.com/jobs/392979'},
#  {'title': 'Digital - API - Lead Software Engineer - SDKs and Connectors',
#   'company': 'FactSet',
#   'location': 'Boston, MA',
#   'link': 'https://stackoverflow.com/jobs/465686'},
#  {'title': 'Join us scale our backend for a better future of housing for everyone',
#   'company': 'Home HT',
#   'location': 'Berlin, Germany',
#   'link': 'https://stackoverflow.com/jobs/201217'},
#  {'title': 'Wissenschaftlicher Mitarbeiter (w/m/d) Software Development',
#   'company': 'Karlsruher Institut für Technologie (KIT) Campus Nord',
#   'location': 'Eggenstein-Leopoldshafen, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/465550'},
#  {'title': 'Backend Engineer (f/m/d) - Madrid',
#   'company': 'Personio',
#   'location': 'Madrid, Spain',
#   'link': 'https://stackoverflow.com/jobs/401726'},
#  {'title': 'Software Engineer - Fullstack (Remote Only)',
#   'company': 'Magic Memories Digital, Ltd.',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/442667'},
#  {'title': 'Front End Engineer',
#   'company': 'Helium',
#   'location': 'Gig Harbor, WA',
#   'link': 'https://stackoverflow.com/jobs/465271'},
#  {'title': 'Senior Manager, Software Development',
#   'company': 'Glowforge',
#   'location': 'Seattle, WA',
#   'link': 'https://stackoverflow.com/jobs/376906'},
#  {'title': 'Developer in Radio Software',
#   'company': 'Ericsson',
#   'location': 'Stockholm, Sweden',
#   'link': 'https://stackoverflow.com/jobs/389814'},
#  {'title': 'Remote Senior Full-stack Software Engineer (EU/UK only)',
#   'company': 'Vavato',
#   'location': 'Sint-Niklaas, Belgium',
#   'link': 'https://stackoverflow.com/jobs/336911'},
#  {'title': 'Senior Backend Engineer (Remote or NYC)',
#   'company': 'Noom',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/283527'},
#  {'title': 'AWS Cloud Consultant',
#   'company': 'Mphasis-Stelligent',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/429899'},
#  {'title': 'Software Engineer (Ruby on Rails)',
#   'company': 'Nikola Corporation',
#   'location': 'Phoenix, AZ',
#   'link': 'https://stackoverflow.com/jobs/442212'},
#  {'title': 'DevOps Engineer - London',
#   'company': 'The Orchard',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/371376'},
#  {'title': 'DevOps Engineer (m/w/d)',
#   'company': 'Mimacom',
#   'location': 'Stuttgart, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/372989'},
#  {'title': 'Singapore SUSE Customer Support',
#   'company': 'SUSE',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/442182'},
#  {'title': 'Senior Software Engineer',
#   'company': 'Driver and Vehicle Licensing Agency (DVLA)',
#   'location': 'Swansea, UK',
#   'link': 'https://stackoverflow.com/jobs/477965'},
#  {'title': 'Senior Software Engineer - Remote Working',
#   'company': 'Driver and Vehicle Licensing Agency (DVLA)',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/477964'},
#  {'title': 'Lead Site Reliability Engineer',
#   'company': 'Mastercard',
#   'location': 'Dublin, Ireland',
#   'link': 'https://stackoverflow.com/jobs/442171'},
#  {'title': 'Lead BizOps Engineer',
#   'company': 'Mastercard',
#   'location': 'Dublin, Ireland',
#   'link': 'https://stackoverflow.com/jobs/442170'},
#  {'title': 'Mid-Level Front-end Responsive Developer',
#   'company': 'Graphic Language',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/418286'},
#  {'title': 'Senior Backend Developer f/m/d',
#   'company': 'Platogo Interactive Entertainment GmbH',
#   'location': 'Wien, Austria',
#   'link': 'https://stackoverflow.com/jobs/379663'},
#  {'title': 'Senior full-stack engineer (Go, React, AWS)',
#   'company': 'Arcivr',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/417931'},
#  {'title': 'Senior Backend Developer (f/m/d) at the leading provider of data rooms in Europe',
#   'company': 'Drooms GmbH',
#   'location': 'Frankfurt am Main, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/372347'},
#  {'title': 'Senior Full Stack Engineer (Angular/Ruby) (Remote)',
#   'company': 'X-Team',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/477311'},
#  {'title': 'Senior Backend Engineer in Full Remote Environment',
#   'company': 'Laboratik',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/441729'},
#  {'title': 'Big Data & Cloud QA Automation Engineer Platform Team',
#   'company': 'Mimecast',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/463993'},
#  {'title': 'Equity Derivatives Technology - C#/ Java Developer, Assoc/VP',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Hong Kong',
#   'link': 'https://stackoverflow.com/jobs/477062'},
#  {'title': 'Cloud DevOps Engineer',
#   'company': 'Tenet3',
#   'location': 'Dayton, OH',
#   'link': 'https://stackoverflow.com/jobs/454614'},
#  {'title': 'Site Reliability Engineer - SRE (Cloud Platform Department) : CPD',
#   'company': 'Rakuten',
#   'location': 'Tokyo, Japan',
#   'link': 'https://stackoverflow.com/jobs/360637'},
#  {'title': 'Software Engineer III',
#   'company': 'G2.com, Inc.',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/441173'},
#  {'title': 'Sr. Software Engineer',
#   'company': 'G2.com, Inc.',
#   'location': 'Chicago, IL',
#   'link': 'https://stackoverflow.com/jobs/441172'},
#  {'title': 'Cloud Platform Software Engineer ( Platform / Back-end / Web) : CPD',
#   'company': 'Rakuten',
#   'location': 'Tokyo, Japan',
#   'link': 'https://stackoverflow.com/jobs/360634'},
#  {'title': 'Senior Software Developer, RDSM',
#   'company': 'Resultados Digitais',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/454416'},
#  {'title': 'Senior Site Reliability Engineer',
#   'company': 'Mollie',
#   'location': 'Amsterdam, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/463471'},
#  {'title': 'Ruby / Elixir Developer',
#   'company': 'Scripbox',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/463464'},
#  {'title': 'Senior Backend Web Developer with an interest in Media Production',
#   'company': 'Qyre AB',
#   'location': 'Stockholm, Sweden',
#   'link': 'https://stackoverflow.com/jobs/463449'},
#  {'title': 'Backend Engineer (Zurich)',
#   'company': 'Yova AG',
#   'location': 'Zürich, Switzerland',
#   'link': 'https://stackoverflow.com/jobs/463436'},
#  {'title': 'Backend Software Engineer - iGaming',
#   'company': 'Booming Games Malta Ltd.',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/463442'},
#  {'title': 'Backend Developer - iGaming',
#   'company': 'Booming Games Malta Ltd.',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/463439'},
#  {'title': 'Sr. or Lead Site Reliability Engineer (Kubernetes) - MariaDB - Fully Remote',
#   'company': 'MariaDBviaSource Coders',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/463349'},
#  {'title': 'Senior Data Engineer',
#   'company': 'Evidation Health',
#   'location': 'San Mateo, CA',
#   'link': 'https://stackoverflow.com/jobs/336565'},
#  {'title': 'Senior/Staff DevOps Engineer',
#   'company': 'Evidation Health',
#   'location': 'Santa Barbara, CA',
#   'link': 'https://stackoverflow.com/jobs/336567'},
#  {'title': 'Engineering Manager - Infrastructure',
#   'company': 'Yelp',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/282014'},
#  {'title': 'System Engineer Linux (m/w), 80-100 %',
#   'company': 'CONCORDIA',
#   'location': 'Luzern, Schweiz',
#   'link': 'https://stackoverflow.com/jobs/417137'},
#  {'title': 'Senior Ruby on Rails Software Engineer',
#   'company': 'Leadfeeder',
#   'location': 'Helsinki, Finland',
#   'link': 'https://stackoverflow.com/jobs/463020'},
#  {'title': 'Full Stack Java Developer',
#   'company': 'Brazen Technologies',
#   'location': 'Arlington, VA',
#   'link': 'https://stackoverflow.com/jobs/413576'},
#  {'title': 'Remote Developer for Global Fintech - LatAm',
#   'company': 'Tutuka',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/427725'},
#  {'title': 'Remote Developer for Global Fintech - SE Asia',
#   'company': 'Tutuka',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/427720'},
#  {'title': 'Server-side Software Developer',
#   'company': 'Network Guard',
#   'location': 'Singapore',
#   'link': 'https://stackoverflow.com/jobs/462638'},
#  {'title': 'Senior PHP Developer (m/f/x)',
#   'company': 'Sonoma Internet GmbH | AMORELIE',
#   'location': 'Berlin, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/462616'},
#  {'title': 'Backend Engineer',
#   'company': 'Ascendify',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/475060'},
#  {'title': 'Software Engineer II, Ruby (I&AM Team)',
#   'company': 'BigCommerce',
#   'location': 'Austin, TX',
#   'link': 'https://stackoverflow.com/jobs/474792'},
#  {'title': 'Senior Applications Security Engineer',
#   'company': 'BigCommerce',
#   'location': 'Austin, TX',
#   'link': 'https://stackoverflow.com/jobs/422200'},
#  {'title': 'Senior Software Engineer, Full Stack',
#   'company': 'Qualia Labs, Inc',
#   'location': 'San Francisco, CA',
#   'link': 'https://stackoverflow.com/jobs/438599'},
#  {'title': 'Lead Software Engineer, Ruby',
#   'company': 'BigCommerce',
#   'location': 'Austin, TX',
#   'link': 'https://stackoverflow.com/jobs/370598'},
#  {'title': 'Software Engineering Manager at interactive benefits communications platform',
#   'company': 'The Jellyvision Lab Inc.',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/474788'},
#  {'title': 'Sr or Lead Full Stack Engineer - Cisco Meraki - Remote, SF, Chicago or Austin',
#   'company': 'Cisco MerakiviaSource Coders',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/462303'},
#  {'title': 'Full Stack Developer at Health Startup (Elixir / Ruby)',
#   'company': 'BetterDoc',
#   'location': 'Cologne, Germany',
#   'link': 'https://stackoverflow.com/jobs/474740'},
#  {'title': 'Ruby Backend Developer',
#   'company': 'aklamio',
#   'location': 'Berlin, Germany',
#   'link': 'https://stackoverflow.com/jobs/474468'},
#  {'title': 'Senior Software Developer (w/m/d) E-Commerce | Team ShoZu',
#   'company': 'Otto (GmbH & Co KG)',
#   'location': 'Hamburg, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/461381'},
#  {'title': 'Lead Software Engineer',
#   'company': 'Unscene',
#   'location': 'Tokyo, Japan',
#   'link': 'https://stackoverflow.com/jobs/474465'},
#  {'title': 'Senior Software Development Engineer - Remote',
#   'company': 'Pixelogic Media',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/439583'},
#  {'title': 'Ruby on Rails Engineer',
#   'company': 'DailyPay, Inc.',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/355854'},
#  {'title': 'Senior Software Engineer',
#   'company': 'Care.com',
#   'location': 'Austin, TX',
#   'link': 'https://stackoverflow.com/jobs/452413'},
#  {'title': 'Ruby on Rails Developer',
#   'company': 'Authority Partners',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/474128'},
#  {'title': 'Senior Backend Engineer',
#   'company': 'Runtastic',
#   'location': 'Linz, Austria',
#   'link': 'https://stackoverflow.com/jobs/390668'},
#  {'title': 'Staff Software Engineer',
#   'company': 'Wikimedia Foundation, Inc.',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/473497'},
#  {'title': 'Full Stack Engineer - Intermediate ( Remote )',
#   'company': 'New Context Services',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/473488'},
#  {'title': 'Lead Developer: Ruby on Rails',
#   'company': 'DaoCloud',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/473487'},
#  {'title': 'Ruby on Rails Developer',
#   'company': 'Nebulab',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/451988'},
#  {'title': 'Senior DevOps Engineer',
#   'company': 'Stott and May Inc.viaStott and May Inc.',
#   'location': 'McLean, VA',
#   'link': 'https://stackoverflow.com/jobs/451932'},
#  {'title': 'Full Stack Software Engineer: Ruby on Rails (m/f/d)',
#   'company': 'creditshelf',
#   'location': 'Frankfurt am Main, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/220001'},
#  {'title': 'DevOps Engineer (m/w/d)',
#   'company': 'Mimacom',
#   'location': 'Stuttgart, Germany',
#   'link': 'https://stackoverflow.com/jobs/473436'},
#  {'title': 'Cloud Security Engineer (f/m/x)',
#   'company': 'AUTO1',
#   'location': 'Berlin, Germany',
#   'link': 'https://stackoverflow.com/jobs/418155'},
#  {'title': 'Staff Engineer, iOS',
#   'company': 'MasterClass',
#   'location': 'San Francisco, CA',
#   'link': 'https://stackoverflow.com/jobs/406302'},
#  {'title': 'Devops Engineer',
#   'company': 'Wishpond Technologies Inc.',
#   'location': 'Vancouver, BC, Canada',
#   'link': 'https://stackoverflow.com/jobs/451589'},
#  {'title': 'Senior Ruby on Rail Web Developer',
#   'company': 'Wishpond Technologies Inc.',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/13682'},
#  {'title': '(100% Remote) Senior Software Engineer in Test',
#   'company': 'Toptal',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/440232'},
#  {'title': 'Senior Front-End Engineer (React)',
#   'company': 'Varsity Tutors',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/461403'},
#  {'title': 'Senior DevOps Engineer',
#   'company': 'Sailpoint Technologies, Inc.',
#   'location': 'Austin, TX',
#   'link': 'https://stackoverflow.com/jobs/415829'},
#  {'title': 'Senior Engineer DevOps Platform',
#   'company': 'Sailpoint Technologies, Inc.',
#   'location': 'Austin, TX',
#   'link': 'https://stackoverflow.com/jobs/415729'},
#  {'title': 'Games Build Engineer / Tools Programmer',
#   'company': 'kwalee Ltd',
#   'location': 'Royal Leamington Spa, UK',
#   'link': 'https://stackoverflow.com/jobs/415705'},
#  {'title': 'Senior Site Reliability Engineer, DevOps',
#   'company': 'DraftKings',
#   'location': 'Boston, MA',
#   'link': 'https://stackoverflow.com/jobs/373255'},
#  {'title': 'Software Engineer (Elixir/Ruby) – mit Homeoffice und Weiterbildungsbudget',
#   'company': 'Studitemps',
#   'location': 'Köln, Germany',
#   'link': 'https://stackoverflow.com/jobs/206267'},
#  {'title': 'Full-stack engineer (JS + Ruby)',
#   'company': 'Almanac',
#   'location': 'San Francisco, CA',
#   'link': 'https://stackoverflow.com/jobs/371120'},
#  {'title': '소만사 2021년 각 부문 신입/경력',
#   'company': '소만사',
#   'location': '서울 영등포구',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=d53efb7ff073f84e'},
#  {'title': '시스템/서버 엔지니어 영입',
#   'company': '카카오페이증권',
#   'location': '성남 분당구',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=a4789c5b4acf4353'},
#  {'title': '[KBS미디어/웹퍼블리셔]',
#   'company': '모닝인',
#   'location': '서울 영등포구',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=a41e3267101efddd'},
#  {'title': 'Ruby on Rails 백엔드 개발자(신입/경력)',
#   'company': 'myrealtrip',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=284ee205d0cfdd97'},
#  {'title': '빅데이터 AI전문 프로그래머',
#   'company': '지엘티코리아',
#   'location': '서울 강남구',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=005d638af6ebafc4'},
#  {'title': 'System Engineer',
#   'company': 'Toss',
#   'location': '서울 강남구',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=80dea8b8353c3ee0'},
#  {'title': 'Developer / Designer recruit',
#   'company': '마이뮤직테이스트',
#   'location': '서울 논현동',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=55a19c92c845685e'},
#  {'title': 'Application Developer',
#   'company': 'Amazon Web Services Korea LLC',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=56ef71094815c15d'},
#  {'title': '드론 데이터 스타트업, 엔젤스윙 엔지니어',
#   'company': '엔젤스윙',
#   'location': '서울 관악구',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=d017610d9828199c'},
#  {'title': 'Datacenter Engineer (강원도 춘천 근무)',
#   'company': 'Oracle',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=e26f899b8accca1a'},
#  {'title': 'JAVA 전문 프로그래머',
#   'company': '지엘티코리아',
#   'location': '서울 강남구',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=69c478938cc3b12e'},
#  {'title': 'Support Engineer _ Developer Support',
#   'company': 'Microsoft',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=7449dd28faebd96c'},
#  {'title': '서버개발자(주니어, 시니어)',
#   'company': '넥스트매치',
#   'location': '서울 서초구',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=6a49ea76da8d2265'},
#  {'title': '서울 강남구 인썸니아 시니어 개발자 및 퍼블리셔',
#   'company': '인썸니아',
#   'location': '서울 서초구',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=6c1d50662fa2d7f7'},
#  {'title': 'Back-end 서버개발자 영입',
#   'company': '카카오모빌리티',
#   'location': '성남 분당구',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=f08dcdd7b602ceb4'},
#  {'title': 'Associate Solutions Architect',
#   'company': 'Amazon Web Services Korea LLC',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=94f4ff49978459bc'},
#  {'title': '하이브리드 앱 개발자',
#   'company': '밋잇챗',
#   'location': '서울 역삼동',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=ba68cf9c91dc27c0'},
#  {'title': '(주)넷타겟 연구원 (웹프론트엔드 개발자)',
#   'company': '넷타겟',
#   'location': '대전 유성구',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=0feb2770202a5be1'},
#  {'title': 'DevOps Engineer (경력)',
#   'company': '데브시스터즈',
#   'location': '서울 강남구',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=20c287566cd343b7'},
#  {'title': 'Technical Trainer - Amazon Web Services',
#   'company': 'Amazon Web Services Korea LLC',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=4e11ecf7b61a8745'},
#  {'title': 'Cloud Solution Architect',
#   'company': 'Microsoft',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=90dd75e589949e62'},
#  {'title': '일삼헤르츠(주) 웹개발 서비스 개발자 경력직',
#   'company': '일삼헤르츠',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=5003a0c1eab64760'},
#  {'title': '인증아이템 신규 플랫폼 서버 개발자 모집',
#   'company': '카카오',
#   'location': '성남 판교역',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=3c1331c8e7e611fe'},
#  {'title': '[Engineering] Front-end Developer',
#   'company': 'Miso, inc',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=9f7d7cbe5e172a01'},
#  {'title': 'Senior Consulting Engineer (APAC)',
#   'company': 'MongoDB',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=f4bc98df496ca222'},
#  {'title': 'MVP 개발 엔지니어(서버, 웹프론트) (정규직, 계약직, 프리랜서)',
#   'company': '더테스터',
#   'location': '대전 중구',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=1748baa27965fdbf'},
#  {'title': 'Principal, Operations Research (Logistics Strategic Capacity Planning)',
#   'company': 'Coupang',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=c2c76ec2dcddb7e5'},
#  {'title': 'Video Solution System Engineer',
#   'company': 'Success Korea',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=838599aa8cfbcf47'},
#  {'title': 'Application Architect',
#   'company': 'Amazon Web Services Korea LLC',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=c1dd526d9a03c05b'},
#  {'title': '웹/서버 개발자',
#   'company': '밋잇챗',
#   'location': '서울 역삼동',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=c6b6b5872b0e6ab1'},
#  {'title': '[Engineering] Back-end Developer',
#   'company': 'Miso, inc',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=80d3108dade97b0f'},
#  {'title': '[Engineering] Full Stack Developer',
#   'company': 'Miso, inc',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=754348a9c3f08d66'},
#  {'title': 'Consultant - Identity & Security',
#   'company': 'Microsoft',
#   'location': '대한민국',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=f71d35f5dff01c45'},
#  {'title': 'Solution Architecture: Starts-Up/Gaming',
#   'company': 'Success Korea',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=6ae76a6437a8a2b6'},
#  {'title': 'Database Consultant, South Korea',
#   'company': 'EDB',
#   'location': '경기도',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=c74c99c413a34fae'},
#  {'title': 'Mid-Market Sales Engineer',
#   'company': 'DataDog',
#   'location': '대한민국',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=52a593e64d404756'},
#  {'title': '[Design] Product Designer (Senior)',
#   'company': 'Miso, inc',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=8931aec27788310e'},
#  {'title': 'Senior Technical Account Manager- AMAZON Web Services, Korea',
#   'company': 'Amazon Web Services Korea LLC',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=ac5e8e3dc9fcd4bb'},
#  {'title': 'qe 소프트웨어 엔지니어',
#   'company': '에이치알 코리아',
#   'location': '대한민국',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=85687b250386c4be'},
#  {'title': '백엔드 개발 경력직',
#   'company': '외국계 대형 플랫폼사',
#   'location': '대한민국',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=58dced95ce3035cd'},
#  {'title': '서버개발',
#   'company': 'Success Korea',
#   'location': '성남 판교역',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=543c76f58bfe472d'},
#  {'title': '광고서버개발',
#   'company': 'Success Korea',
#   'location': '서울 강남구',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=cb7b4fc663c0fa0a'},
#  {'title': 'MIS개발',
#   'company': 'Success Korea',
#   'location': '대한민국',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=ae3f481194bf6a6a'},
#  {'title': 'M&E Specialist Solutions Architect',
#   'company': 'Amazon Web Services Korea LLC',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=89bccf4060ac7546'},
#  {'title': '[Engineering] React Native Developer',
#   'company': 'Miso, inc',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=315c65b8337d3e7a'},
#  {'title': '웹개발',
#   'company': 'Success Korea',
#   'location': '서울 강남구',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=2279ea5ffec3e1ec'},
#  {'title': 'Full Stack Software Engineer (South Korea)',
#   'company': 'ChartMogul CMTDE GmbH & Co. KG',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=af83f08facf40575'},
#  {'title': '서버 개발',
#   'company': 'Success Korea',
#   'location': '서울 강남구',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=c976b0b7099e286e'},
#  {'title': 'SW개발 매니저',
#   'company': 'Success Korea',
#   'location': '서울 삼성동',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=a758b91ea2f0dd2b'},
#  {'title': '웹개발자',
#   'company': 'Success Korea',
#   'location': '서울 잠실역',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=2936adf2a7318db5'},
#  {'title': '웹개발팀장',
#   'company': 'Success Korea',
#   'location': '서울 잠실역',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=c4e7809eb035c7ee'},
#  {'title': 'Software Engineer in Test (SET)',
#   'company': 'Success Korea',
#   'location': '성남 분당구',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=4958c02183a2ccce'},
#  {'title': 'Consultant - Cloud Infra',
#   'company': 'Microsoft',
#   'location': '대한민국',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=e76292662d915031'},
#  {'title': 'SW개발(3명)',
#   'company': 'Success Korea',
#   'location': '서울 삼성동',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=989584aa51f96aa1'},
#  {'title': 'Backend Developer(Python or Java)',
#   'company': 'Success Korea',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=3383326062c40ec2'},
#  {'title': 'Sydney Based Cloud Support Engineer',
#   'company': 'Success Korea',
#   'location': '대한민국',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=449c79ff66c3925c'},
#  {'title': 'Full Stack Senior 개발자',
#   'company': 'Success Korea',
#   'location': '서울 강남구',
#   'link': 'https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3%B4%EA%B8%B0?jk=75a1f925e5637e4d'}]

# %% [markdown]
# ### 총 데이터 갯수

# %%
len(jobs)
# Out:
# 364

# %% [markdown]
# ##  csv파일 형식으로 저장

# %%
from save import save_to_file

# %%
save_to_file(jobs)

# %% [markdown]
# ## 데이터 프레임으로 출력

# %%
import pandas as pd
df = pd.read_csv("jobs.csv")

# %%
df
# Out:
#                                                  title  \
# 0                                 Software Engineering
# 1               Full Stack Engineer - Remote, USA ONLY
# 2                 Software Engineer (Backend) - NYC/LA
# 3    Sr. Software Engineer - Ruby - Telehealth / Te...
# 4    Software Engineer Ruby/Elixir for Internet of ...
# ..                                                 ...
# 359                           Consultant - Cloud Infra
# 360                                           SW개발(3명)
# 361                  Backend Developer(Python or Java)
# 362                Sydney Based Cloud Support Engineer
# 363                              Full Stack Senior 개발자
#
#                        company             location  \
# 0    JPMorgan Chase Bank, N.A.       Wilmington, DE
# 1                 SocialChorus   No office location
# 2         Gravity Technologies         New York, NY
# 3                     VisuWell        Nashville, TN
# 4                  sonnen GmbH  Berlin, Deutschland
# ..                         ...                  ...
# 359                  Microsoft                 대한민국
# 360              Success Korea               서울 삼성동
# 361              Success Korea                   서울
# 362              Success Korea                 대한민국
# 363              Success Korea               서울 강남구
#
#                                                   link
# 0                https://stackoverflow.com/jobs/487157
# 1                https://stackoverflow.com/jobs/371379
# 2                https://stackoverflow.com/jobs/194557
# 3                https://stackoverflow.com/jobs/487286
# 4                https://stackoverflow.com/jobs/487278
# ..                                                 ...
# 359  https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3...
# 360  https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3...
# 361  https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3...
# 362  https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3...
# 363  https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3...
#
# [364 rows x 4 columns]
