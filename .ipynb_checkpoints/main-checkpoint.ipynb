# %% [markdown]
# ## Indeed 사이트에서 Python 검색했을 시의 데이터(직무, 회사, 위치, 구인링크) 출력

# %%
from indeed import get_jobs as get_indeed_jobs
from so import get_jobs as get_so_jobs
import requests
from save import save_to_file
import pandas as pd

# %%
indeed_jobs = get_indeed_jobs()
# Out:
# Scrapping Indeed page 0
# Scrapping Indeed page 1
# Scrapping Indeed page 2
# Scrapping Indeed page 3
# Scrapping Indeed page 4
# Scrapping Indeed page 5
# Scrapping Indeed page 6
# Scrapping Indeed page 7
# Scrapping Indeed page 8
# Scrapping Indeed page 9
# Scrapping Indeed page 10
# Scrapping Indeed page 11
# Scrapping Indeed page 12
# Scrapping Indeed page 13
# Scrapping Indeed page 14
# Scrapping Indeed page 15
# Scrapping Indeed page 16
# Scrapping Indeed page 17
# Scrapping Indeed page 18

# %% [markdown]
# ## StackoverFlow 사이트에서 Python 검색했을 시의 데이터(직무, 회사, 위치, 구인링크) 출력

# %%
so_jobs =get_so_jobs()
# Out:
# Scrapping SO page 0
# Scrapping SO page 1
# Scrapping SO page 2
# Scrapping SO page 3
# Scrapping SO page 4
# Scrapping SO page 5
# Scrapping SO page 6
# Scrapping SO page 7
# Scrapping SO page 8
# Scrapping SO page 9
# Scrapping SO page 10
# Scrapping SO page 11
# Scrapping SO page 12
# Scrapping SO page 13
# Scrapping SO page 14
# Scrapping SO page 15
# Scrapping SO page 16
# Scrapping SO page 17
# Scrapping SO page 18
# Scrapping SO page 19
# Scrapping SO page 20
# Scrapping SO page 21
# Scrapping SO page 22
# Scrapping SO page 23
# Scrapping SO page 24
# Scrapping SO page 25
# Scrapping SO page 26
# Scrapping SO page 27
# Scrapping SO page 28
# Scrapping SO page 29
# Scrapping SO page 30
# Scrapping SO page 31
# Scrapping SO page 32
# Scrapping SO page 33
# Scrapping SO page 34
# Scrapping SO page 35
# Scrapping SO page 36
# Scrapping SO page 37
# Scrapping SO page 38
# Scrapping SO page 39
# Scrapping SO page 40
# Scrapping SO page 41
# Scrapping SO page 42
# Scrapping SO page 43
# Scrapping SO page 44
# Scrapping SO page 45
# Scrapping SO page 46
# Scrapping SO page 47
# Scrapping SO page 48
# Scrapping SO page 49
# Scrapping SO page 50
# Scrapping SO page 51
# Scrapping SO page 52
# Scrapping SO page 53
# Scrapping SO page 54
# Scrapping SO page 55
# Scrapping SO page 56
# Scrapping SO page 57
# Scrapping SO page 58
# Scrapping SO page 59
# Scrapping SO page 60
# Scrapping SO page 61
# Scrapping SO page 62
# Scrapping SO page 63
# Scrapping SO page 64
# Scrapping SO page 65
# Scrapping SO page 66
# Scrapping SO page 67
# Scrapping SO page 68
# Scrapping SO page 69
# Scrapping SO page 70
# Scrapping SO page 71
# Scrapping SO page 72
# Scrapping SO page 73
# Scrapping SO page 74
# Scrapping SO page 75
# Scrapping SO page 76
# Scrapping SO page 77
# Scrapping SO page 78
# Scrapping SO page 79
# Scrapping SO page 80
# Scrapping SO page 81
# Scrapping SO page 82
# Scrapping SO page 83
# Scrapping SO page 84
# Scrapping SO page 85
# Scrapping SO page 86
# Scrapping SO page 87
# Scrapping SO page 88

# %%
jobs = so_jobs + indeed_jobs

# %%
jobs
# Out:
# [{'title': 'Python Software Engineer',
#   'company': 'bloomon',
#   'location': 'Amsterdam, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/286140'},
#  {'title': 'Senior Backend Engineer (Python/Django)',
#   'company': 'NewtonX',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/470973'},
#  {'title': 'Remote Senior Software Engineer, Python',
#   'company': 'Verys',
#   'location': 'Santa Ana, CA',
#   'link': 'https://stackoverflow.com/jobs/469797'},
#  {'title': 'Senior Software Engineer (Python)',
#   'company': 'HealthJoy',
#   'location': 'Kyiv, Ukraine',
#   'link': 'https://stackoverflow.com/jobs/457700'},
#  {'title': 'Python Web Developer',
#   'company': 'RavenPack International SL.',
#   'location': 'Marbella, Spain',
#   'link': 'https://stackoverflow.com/jobs/470988'},
#  {'title': 'Software Developer (Python)',
#   'company': 'Nexthink',
#   'location': 'Prilly, Switzerland',
#   'link': 'https://stackoverflow.com/jobs/471159'},
#  {'title': 'Mid-level Python and Django software developer',
#   'company': 'Eligible.ai',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/447951'},
#  {'title': 'Senior Software Engineer - Python',
#   'company': 'YouGov',
#   'location': 'Warsaw, Poland',
#   'link': 'https://stackoverflow.com/jobs/422635'},
#  {'title': 'Backend Software Engineer (Python)',
#   'company': 'Axomic Inc',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/468959'},
#  {'title': 'Fullstack Software Engineer (JavaScript, Python)',
#   'company': 'F-Secure',
#   'location': 'Poznań, Poland',
#   'link': 'https://stackoverflow.com/jobs/470808'},
#  {'title': 'Senior BackEnd Software Engineer - Python, AWS',
#   'company': 'Handiscover ABvianetObjectives',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/468497'},
#  {'title': 'Senior Python Back End Engineer (Remote)',
#   'company': 'Loadsmart',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/430974'},
#  {'title': 'Python Software Developer',
#   'company': 'Old Mission Capital, LLC',
#   'location': 'Chicago, IL',
#   'link': 'https://stackoverflow.com/jobs/237203'},
#  {'title': 'Experienced Full-Stack Engineer (Python/Django)',
#   'company': 'CareSolace Inc.',
#   'location': 'Encinitas, CA',
#   'link': 'https://stackoverflow.com/jobs/452576'},
#  {'title': 'Senior Backend Engineer (Python/Django)',
#   'company': 'Financial Technology Partners',
#   'location': 'San Francisco, CA',
#   'link': 'https://stackoverflow.com/jobs/446918'},
#  {'title': 'Software Engineering- Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/469811'},
#  {'title': 'Senior Backend Software Engineer - Python',
#   'company': 'Advertima',
#   'location': 'Berlin, Germany',
#   'link': 'https://stackoverflow.com/jobs/465088'},
#  {'title': 'Senior Software Developer Python (m/f/d)',
#   'company': 'Ströer Online Marketing',
#   'location': 'Hamburg, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/462625'},
#  {'title': 'Python Full Stack Developer',
#   'company': 'Draft2Digital',
#   'location': 'Oklahoma City, OK',
#   'link': 'https://stackoverflow.com/jobs/313165'},
#  {'title': 'Senior Full-stack web developer - Python',
#   'company': 'CBOE Global MarketsviaHays PLC',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/355023'},
#  {'title': 'Mid-Level Backend Software Engineer (Python / Django)',
#   'company': 'Tivix, Inc.',
#   'location': 'Wrocław, Poland',
#   'link': 'https://stackoverflow.com/jobs/420639'},
#  {'title': 'Senior Python Engineer (Remote)',
#   'company': 'X-Team',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/445852'},
#  {'title': 'Octopus Energy is still hiring for Python/Django Engineers!',
#   'company': 'Octopus Energy',
#   'location': 'Melbourne, Australia',
#   'link': 'https://stackoverflow.com/jobs/468929'},
#  {'title': 'Python Software Engineer',
#   'company': 'Captivation Software',
#   'location': 'Fort Meade, MD',
#   'link': 'https://stackoverflow.com/jobs/449506'},
#  {'title': 'Python Software Engineer (40h/wk)',
#   'company': 'Channable',
#   'location': 'Utrecht, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/458136'},
#  {'title': 'Software Engineering - Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/472158'},
#  {'title': 'Backend Developer – Python/Django',
#   'company': '5 Monkeys Agency AB',
#   'location': 'Stockholm, Sweden',
#   'link': 'https://stackoverflow.com/jobs/443604'},
#  {'title': 'Senior Backend Engineer - Python',
#   'company': 'APNATIME TECH PRIVATE LIMITED',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/411044'},
#  {'title': 'Software Engineer Data Science (SQL & Python)',
#   'company': 'SAP',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/448509'},
#  {'title': 'Python Developer - REMOTE',
#   'company': 'Pentalog',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/470995'},
#  {'title': 'Senior Python Developer',
#   'company': 'YouGov',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/400054'},
#  {'title': 'Python Full Stack Developer',
#   'company': 'Draft2Digital',
#   'location': 'Oklahoma City, OK',
#   'link': 'https://stackoverflow.com/jobs/313165'},
#  {'title': 'Python Developer - REMOTE',
#   'company': 'Pentalog',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/470999'},
#  {'title': 'Senior Full-stack web developer - Python',
#   'company': 'CBOE Global MarketsviaHays PLC',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/355023'},
#  {'title': 'Rust / Python Developer',
#   'company': 'YouGov',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/469780'},
#  {'title': 'Python Developer',
#   'company': 'Octopus Energy',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/468269'},
#  {'title': 'Senior Python Engineer (Remote)',
#   'company': 'X-Team',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/445852'},
#  {'title': 'Python Developer',
#   'company': 'YouGov',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/463034'},
#  {'title': 'Senior Software Engineer Backend Python (m/f/d)',
#   'company': 'BASF',
#   'location': 'Köln, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/466263'},
#  {'title': 'Senior Python Engineer',
#   'company': 'Tivix',
#   'location': 'Wrocław, Poland',
#   'link': 'https://stackoverflow.com/jobs/420641'},
#  {'title': 'Python Software Engineer (40h/wk)',
#   'company': 'Channable',
#   'location': 'Utrecht, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/265091'},
#  {'title': 'Senior Python Engineer',
#   'company': 'Bulb Energy',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/396265'},
#  {'title': 'Python Software Engineer (40h/wk)',
#   'company': 'Channable',
#   'location': 'Utrecht, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/458136'},
#  {'title': 'Python/Django Software Developer (m/f/d)',
#   'company': 'ClimatePartner',
#   'location': 'München, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/361172'},
#  {'title': 'Lead Software Engineer - Python - ASOS AI',
#   'company': 'ASOS',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/455785'},
#  {'title': 'Python developer for VoIP service provider',
#   'company': 'TelSmart',
#   'location': 'Zagreb, Croatia',
#   'link': 'https://stackoverflow.com/jobs/435753'},
#  {'title': 'Independent & Self-motivated Senior Python Backend Developer',
#   'company': 'Seez',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/394457'},
#  {'title': 'Senior Python Backend Developer (m/f/x)',
#   'company': 'Innoactive GmbH',
#   'location': 'München, Germany',
#   'link': 'https://stackoverflow.com/jobs/412785'},
#  {'title': 'Backend Engineer - Python (m/f/d)',
#   'company': 'Laya Technologies',
#   'location': 'München, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/333801'},
#  {'title': 'Sr. Python Software Engineer',
#   'company': 'Global Reach Consulting LLC',
#   'location': 'Reston, VA',
#   'link': 'https://stackoverflow.com/jobs/417839'},
#  {'title': 'Software Engineer - Java/Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/472164'},
#  {'title': 'Sr. Python Software Engineer',
#   'company': 'Global Reach Consulting LLC',
#   'location': 'Reston, VA',
#   'link': 'https://stackoverflow.com/jobs/417839'},
#  {'title': '(Senior) Python Developer Backend – Billing / Product',
#   'company': 'Lumenaza GmbH',
#   'location': 'Berlin, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/359016'},
#  {'title': 'Python / Django Engineer',
#   'company': 'Potato',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/463168'},
#  {'title': 'Awesome Full-Stack Software Engineer - Java, Python, Spark(Fully Cleared)',
#   'company': 'Erias Ventures',
#   'location': 'Annapolis Junction, MD',
#   'link': 'https://stackoverflow.com/jobs/432032'},
#  {'title': 'Software Engineer- Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Glasgow, UK',
#   'link': 'https://stackoverflow.com/jobs/472211'},
#  {'title': 'Python Developer, Full-Time Job in Bucharest',
#   'company': 'SkillValue',
#   'location': 'Bucharest, Romania',
#   'link': 'https://stackoverflow.com/jobs/460151'},
#  {'title': 'Senior Backend Software Engineer (Python)',
#   'company': 'Curative, Inc',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/408170'},
#  {'title': 'Lead Developer Backend / Softwarearchitekt (m/w/d) Python/Django',
#   'company': 'Bundesdruckerei GmbH',
#   'location': 'Hamburg, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/468265'},
#  {'title': 'Data engineer / Dev backend python',
#   'company': 'PandaScore',
#   'location': 'Paris, France',
#   'link': 'https://stackoverflow.com/jobs/450829'},
#  {'title': 'Senior Python Developer (m/f/d)',
#   'company': 'Fashion Cloud',
#   'location': 'Amsterdam, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/467737'},
#  {'title': 'Senior Full Stack Software Engineer – Python/JavaScript (m/f/d)',
#   'company': 'CeleraOne GmbH',
#   'location': 'Berlin, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/449456'},
#  {'title': 'Python Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Glasgow, UK',
#   'link': 'https://stackoverflow.com/jobs/471682'},
#  {'title': 'Backend Python Developer (m/f/x)',
#   'company': 'Alasco',
#   'location': 'München, Germany',
#   'link': 'https://stackoverflow.com/jobs/388312'},
#  {'title': 'Software Engineering Lead - Python\\\\Angular',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/471764'},
#  {'title': 'Python/AngularJS Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'link': 'https://stackoverflow.com/jobs/460756'},
#  {'title': 'Python Developer (Software Security Solutions)',
#   'company': 'Bromium UK Limited',
#   'location': 'Cambridge, UK',
#   'link': 'https://stackoverflow.com/jobs/468916'},
#  {'title': 'Python / Java Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/470860'},
#  {'title': 'Python Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'link': 'https://stackoverflow.com/jobs/468375'},
#  {'title': 'Python Developer',
#   'company': 'Cboe Global MarketsviaHays PLC',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/397043'},
#  {'title': 'Lead Python Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Glasgow, UK',
#   'link': 'https://stackoverflow.com/jobs/471639'},
#  {'title': 'Python Developer / Data-Engineer (m/w/d) Textanalyse',
#   'company': 'Bundesdruckerei GmbH',
#   'location': 'Hamburg, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/468266'},
#  {'title': 'Python, C++ Software Engineer for Athena Trade & Risk',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/471290'},
#  {'title': 'Software Engineering - Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Glasgow, UK',
#   'link': 'https://stackoverflow.com/jobs/470517'},
#  {'title': 'Software Engineering - Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Glasgow, UK',
#   'link': 'https://stackoverflow.com/jobs/465296'},
#  {'title': 'Software Engineering - Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Glasgow, UK',
#   'link': 'https://stackoverflow.com/jobs/471629'},
#  {'title': 'Senior Developer - "Kubernetes, Go Lang, Python,  API"',
#   'company': 'SAP',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/454627'},
#  {'title': 'Python, C++ Software Engineer for Athena Trade & Risk',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/471290'},
#  {'title': 'Software Engineering - Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Glasgow, UK',
#   'link': 'https://stackoverflow.com/jobs/470517'},
#  {'title': 'Software Engineering - Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Mumbai, India',
#   'link': 'https://stackoverflow.com/jobs/470169'},
#  {'title': 'Python Developer (Onsite in Paris, or Remote in France, UK, Germany)',
#   'company': 'PeopleDoc',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/471172'},
#  {'title': 'Senior Software Engineer (Java or Python)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Glasgow, UK',
#   'link': 'https://stackoverflow.com/jobs/471818'},
#  {'title': 'Python Software Engineer',
#   'company': 'Trilliant Health',
#   'location': 'Nashville, TN',
#   'link': 'https://stackoverflow.com/jobs/456801'},
#  {'title': 'Software Engineering - Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Buenos Aires, Argentina',
#   'link': 'https://stackoverflow.com/jobs/467670'},
#  {'title': 'Software Engineering - Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Buenos Aires, Argentina',
#   'link': 'https://stackoverflow.com/jobs/470419'},
#  {'title': 'Python Developer (Backend)',
#   'company': 'Energyworx',
#   'location': 'Houten, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/165665'},
#  {'title': 'Software Engineering - Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/469075'},
#  {'title': 'PYTHON DEVELOPER Location: Zürich, Zurich, Switzerland',
#   'company': 'FELFEL',
#   'location': 'Zürich, Switzerland',
#   'link': 'https://stackoverflow.com/jobs/465684'},
#  {'title': 'Python Spark Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Newark, DE',
#   'link': 'https://stackoverflow.com/jobs/465305'},
#  {'title': 'Software Engineering - Python + Spark',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Newark, DE',
#   'link': 'https://stackoverflow.com/jobs/466166'},
#  {'title': 'Full-Stack Python Engineer',
#   'company': 'Gorgias',
#   'location': 'Paris, France',
#   'link': 'https://stackoverflow.com/jobs/333474'},
#  {'title': 'Python Software Developer',
#   'company': 'UBIMET GmbH',
#   'location': 'Wien, Österreich',
#   'link': 'https://stackoverflow.com/jobs/412367'},
#  {'title': 'Software Engineering - Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Buenos Aires, Argentina',
#   'link': 'https://stackoverflow.com/jobs/464670'},
#  {'title': 'Software Engineering - Oracle, Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Mumbai, India',
#   'link': 'https://stackoverflow.com/jobs/470828'},
#  {'title': 'Software Engineering - Java/Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Buenos Aires, Argentina',
#   'link': 'https://stackoverflow.com/jobs/468861'},
#  {'title': 'Python Software Engineer',
#   'company': 'Administrate',
#   'location': 'Beirut, Lebanon',
#   'link': 'https://stackoverflow.com/jobs/371364'},
#  {'title': 'Senior Full Stack Web Software Engineer - React-Java, Python or Node.js',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'link': 'https://stackoverflow.com/jobs/470017'},
#  {'title': 'Senior Java Software Engineer with Python, Kafka experience',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Chicago, IL',
#   'link': 'https://stackoverflow.com/jobs/463799'},
#  {'title': 'Python Developer suchen Kollegen (m/w/d)',
#   'company': 'solute GmbH',
#   'location': 'Karlsruhe, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/284443'},
#  {'title': 'Full Stack Software Engineer: Java / Python (m/f/d)',
#   'company': 'creditshelf',
#   'location': 'Berlin, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/376524'},
#  {'title': 'Senior Java/Python Software engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/471343'},
#  {'title': 'Senior Software Engineer (C++/Python) - Collaboration Frameworks',
#   'company': 'Bloomberg LP',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/449476'},
#  {'title': 'Senior Full Stack Web Software Engineer - React-Java, Python or Node.js',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'link': 'https://stackoverflow.com/jobs/470017'},
#  {'title': 'Python Software Engineer',
#   'company': 'Administrate',
#   'location': 'Beirut, Lebanon',
#   'link': 'https://stackoverflow.com/jobs/371364'},
#  {'title': 'Team Lead Engineering – API/Python (m/f/d)',
#   'company': 'Laya Technologies',
#   'location': 'München, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/416103'},
#  {'title': 'Full Stack Software Engineer: Java / Python (m/f/d)',
#   'company': 'creditshelf',
#   'location': 'Berlin, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/376524'},
#  {'title': 'Senior back-end engineer who loves Python and brains',
#   'company': 'QMENTA',
#   'location': 'Barcelona, Spain',
#   'link': 'https://stackoverflow.com/jobs/454987'},
#  {'title': 'Software Engineering: ServiceNow, AWS & Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Wilmington, DE',
#   'link': 'https://stackoverflow.com/jobs/465307'},
#  {'title': 'Python Data Engineer',
#   'company': 'BitEdgeviaHays PLC',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/420749'},
#  {'title': 'Sr. Python Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/471423'},
#  {'title': 'Senior Software Engineer - Python (d/f/m)',
#   'company': 'arculus',
#   'location': 'Munich, Germany',
#   'link': 'https://stackoverflow.com/jobs/465942'},
#  {'title': 'Senior Software Engineer (Python) - ML Infrastructure',
#   'company': 'NannyML',
#   'location': 'Lisbon, Portugal',
#   'link': 'https://stackoverflow.com/jobs/462712'},
#  {'title': 'Software Engineering - Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Buenos Aires, Argentina',
#   'link': 'https://stackoverflow.com/jobs/468343'},
#  {'title': 'Python Backend Engineer',
#   'company': 'Skillhouse Staffing Solutions',
#   'location': 'Tokyo, Japan',
#   'link': 'https://stackoverflow.com/jobs/465919'},
#  {'title': 'Software Engineering - Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/470152'},
#  {'title': 'Software Engineering - Python/C++',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/469005'},
#  {'title': 'Software Engineering - Python Dev - Bengaluru',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/472166'},
#  {'title': 'Senior Python Developer - Global Technology Infrastructure - Database Services - Vice...',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/462028'},
#  {'title': 'Software Engineer/SRE with Java or Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Wilmington, DE',
#   'link': 'https://stackoverflow.com/jobs/464853'},
#  {'title': 'Python Developer',
#   'company': 'BairesDev LLC',
#   'location': 'San Francisco, CA',
#   'link': 'https://stackoverflow.com/jobs/471587'},
#  {'title': 'Software Engineering - Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Mumbai, India',
#   'link': 'https://stackoverflow.com/jobs/471478'},
#  {'title': 'Python ,Spark Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Mumbai, India',
#   'link': 'https://stackoverflow.com/jobs/471846'},
#  {'title': 'VP Python Software Engineer - Currencies & Emerging Markets - CIB Markets Technology -...',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/471275'},
#  {'title': 'Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/472157'},
#  {'title': 'Python Software Engineering Manager',
#   'company': 'Tempo',
#   'location': 'San Francisco, CA',
#   'link': 'https://stackoverflow.com/jobs/442823'},
#  {'title': 'Big Data and Python Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'link': 'https://stackoverflow.com/jobs/469563'},
#  {'title': 'Big Data Engineer - Python + Spark',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Westerville, OH',
#   'link': 'https://stackoverflow.com/jobs/470464'},
#  {'title': 'Software Engineer (Python Data Stack) (m/f/d)',
#   'company': 'QuantCo',
#   'location': 'Karlsruhe, Germany',
#   'link': 'https://stackoverflow.com/jobs/349976'},
#  {'title': 'Java/Python Engineer for Securitized Products',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/470253'},
#  {'title': 'Java / Python Software Engineer - AWM Trading Technology - Vice President (VP)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/470294'},
#  {'title': 'Python, SQL Engineer for Securitized product AWS platform',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'link': 'https://stackoverflow.com/jobs/469551'},
#  {'title': 'Developer (Python OR JavaScript)',
#   'company': 'Odoo',
#   'location': 'Ramillies, Belgium',
#   'link': 'https://stackoverflow.com/jobs/167359'},
#  {'title': 'Looking for an Amazing Senior Python Developer',
#   'company': 'Tech9',
#   'location': 'Pune, India',
#   'link': 'https://stackoverflow.com/jobs/468707'},
#  {'title': 'Python Developer',
#   'company': 'Anyfin AB',
#   'location': 'Stockholm, Sweden',
#   'link': 'https://stackoverflow.com/jobs/451956'},
#  {'title': 'Software Engineering - Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Mumbai, India',
#   'link': 'https://stackoverflow.com/jobs/466181'},
#  {'title': 'Senior Backend Developer PHP/Python (m/f/d)',
#   'company': 'internetstores GmbH',
#   'location': 'Stuttgart, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/455191'},
#  {'title': 'Big Data Engineer (Spark/Python)',
#   'company': 'Navy Federal Credit Union',
#   'location': 'Vienna, VA',
#   'link': 'https://stackoverflow.com/jobs/461163'},
#  {'title': 'Senior Python Data Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'link': 'https://stackoverflow.com/jobs/471663'},
#  {'title': 'Senior Superhero Python Developer to protect the Bank from counterparty risk',
#   'company': 'Deutsche BankviaJWiderberg Inc. DBA Insight Resource Group',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/453533'},
#  {'title': 'Python Developer (Data Science)',
#   'company': 'IHS Markit',
#   'location': 'Minsk, Belarus',
#   'link': 'https://stackoverflow.com/jobs/470555'},
#  {'title': 'C++, Python Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/469550'},
#  {'title': 'VP Python Software Engineer - FX Services Technology',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/470802'},
#  {'title': 'Python ,Spark Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Mumbai, India',
#   'link': 'https://stackoverflow.com/jobs/471386'},
#  {'title': 'Engineer - Python/Big Data',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Newark, DE',
#   'link': 'https://stackoverflow.com/jobs/469136'},
#  {'title': 'Senior software engineer (Typescript, Nextjs, Python, Docker/k8s, Kafka, AWS)',
#   'company': 'EverQuote Inc.',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/385234'},
#  {'title': 'Senior Python Developer',
#   'company': 'DraftKings',
#   'location': 'Sofia, Bulgaria',
#   'link': 'https://stackoverflow.com/jobs/468484'},
#  {'title': 'Software Engineer - Vice President (Python / Java)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bournemouth, UK',
#   'link': 'https://stackoverflow.com/jobs/465892'},
#  {'title': 'Python Data Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'link': 'https://stackoverflow.com/jobs/471664'},
#  {'title': 'Software Engineering - Python - Mumbai',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Mumbai, India',
#   'link': 'https://stackoverflow.com/jobs/469178'},
#  {'title': 'Full Stack Engineer - Python/JS (d/f/m)',
#   'company': 'Stylight',
#   'location': 'München, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/416801'},
#  {'title': 'Python Engineer',
#   'company': 'TileDB, Inc.',
#   'location': 'Cambridge, MA',
#   'link': 'https://stackoverflow.com/jobs/419347'},
#  {'title': 'QA Engineer (Python/Java)',
#   'company': 'Flow Traders',
#   'location': 'Amsterdam, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/421752'},
#  {'title': 'Java/Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'link': 'https://stackoverflow.com/jobs/467207'},
#  {'title': '[100% REMOTE] Sr. Python Data Engineer',
#   'company': 'Clevertech',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/470792'},
#  {'title': 'Engineer - Python/Big Data',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Newark, DE',
#   'link': 'https://stackoverflow.com/jobs/469136'},
#  {'title': 'Python-Infrastructure Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'link': 'https://stackoverflow.com/jobs/467028'},
#  {'title': 'Python Technical Lead for Commodities (Energy) team',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/468374'},
#  {'title': 'Mid Python Developer',
#   'company': 'OpsTalent',
#   'location': 'Wrocław, Poland',
#   'link': 'https://stackoverflow.com/jobs/450822'},
#  {'title': 'Senior Python Developer',
#   'company': 'Tenfifty AB',
#   'location': 'Göteborg, Sweden',
#   'link': 'https://stackoverflow.com/jobs/461145'},
#  {'title': 'Senior Data Engineer (Python)-Remote',
#   'company': 'SemanticBits',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/466469'},
#  {'title': 'Data Engineer (Java, Python, AWS)',
#   'company': 'Ascend Group',
#   'location': 'Khwaeng Bang Chak, Thailand',
#   'link': 'https://stackoverflow.com/jobs/340997'},
#  {'title': 'Développeur-euse Fullstack (Python/Flask)',
#   'company': 'Fintel SAS',
#   'location': 'Marseille, France',
#   'link': 'https://stackoverflow.com/jobs/465113'},
#  {'title': 'Software Engineer - Vice President (Python / Java)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bournemouth, UK',
#   'link': 'https://stackoverflow.com/jobs/465892'},
#  {'title': 'Python Developer',
#   'company': 'JP Morgan Chase',
#   'location': 'Herzliya, Israel',
#   'link': 'https://stackoverflow.com/jobs/445023'},
#  {'title': 'Machine Learning / Python Engineer - Applied AI Systems - Vice President Software...',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/472139'},
#  {'title': 'Advanced Python Engineer',
#   'company': 'Research Affiliates (Investment Systems)',
#   'location': 'Newport Beach, CA',
#   'link': 'https://stackoverflow.com/jobs/159863'},
#  {'title': 'Python Developer/Data Engineer (Remote - US only)',
#   'company': 'X-Team',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/469782'},
#  {'title': 'Senior Back End Engineer - Java / Kotlin / Python',
#   'company': 'teckro',
#   'location': 'Dublin, Ireland',
#   'link': 'https://stackoverflow.com/jobs/403329'},
#  {'title': 'Senior Python developer',
#   'company': 'Hays London City CheapsideviaHays PLC',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/433870'},
#  {'title': 'Senior Data Engineer (Python, Kafka, Airflow)',
#   'company': 'AMBOSS',
#   'location': 'Berlin, Germany',
#   'link': 'https://stackoverflow.com/jobs/415218'},
#  {'title': 'Infrastructure Developer - Python and Infrastructure',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/466175'},
#  {'title': 'Python Back End Engineer',
#   'company': 'Tempo',
#   'location': 'San Francisco, CA',
#   'link': 'https://stackoverflow.com/jobs/442822'},
#  {'title': 'Full Stack Python Engineer',
#   'company': 'kwalee Ltd',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/415702'},
#  {'title': 'Senior Python Engineer for Distributed Systems',
#   'company': 'Hazelcast',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/454972'},
#  {'title': 'BigData with Spark & Scala/Python/Java',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/467309'},
#  {'title': 'Infrastructure Development (Python, Java, C-Sharp)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Columbus, OH',
#   'link': 'https://stackoverflow.com/jobs/465313'},
#  {'title': 'Mid Python Developer',
#   'company': 'OpsTalent',
#   'location': 'Wrocław, Poland',
#   'link': 'https://stackoverflow.com/jobs/450822'},
#  {'title': 'Senior Python Developer',
#   'company': 'Tenfifty AB',
#   'location': 'Göteborg, Sweden',
#   'link': 'https://stackoverflow.com/jobs/461145'},
#  {'title': 'Python Developer- AWS',
#   'company': 'HaysviaHays PLC',
#   'location': 'Tampa, FL',
#   'link': 'https://stackoverflow.com/jobs/347598'},
#  {'title': 'Sr. Engineering Developer (Python / Go / Ruby) - Remote',
#   'company': 'HaysviaHays PLC',
#   'location': 'Atlanta, GA',
#   'link': 'https://stackoverflow.com/jobs/377138'},
#  {'title': 'DevOps Engineer (AWS, Pivotal, Python, Java)',
#   'company': 'buildit',
#   'location': 'Kraków, Poland',
#   'link': 'https://stackoverflow.com/jobs/298627'},
#  {'title': 'Sr. Java, Python Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/469549'},
#  {'title': 'Python Infrastructure Developer-NAS/File Storage',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Lewisville, TX',
#   'link': 'https://stackoverflow.com/jobs/471287'},
#  {'title': 'Fullstack Developer (m/f/d) (React, Python etc.)',
#   'company': 'Haufe Group',
#   'location': 'Freiburg im Breisgau, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/463897'},
#  {'title': 'Software Engineers - Cloud Reliability & Infrastructure (Python or Java)',
#   'company': 'Canva',
#   'location': 'Sydney, Australia',
#   'link': 'https://stackoverflow.com/jobs/373689'},
#  {'title': 'Data Engineer (m/f) (SQL, Python, R, Java)',
#   'company': 'RIAG DIGITAL',
#   'location': 'Wien, Austria',
#   'link': 'https://stackoverflow.com/jobs/376577'},
#  {'title': 'Senior Data Platform Engineer - Python | Spark',
#   'company': 'Choco',
#   'location': 'Berlin, Germany',
#   'link': 'https://stackoverflow.com/jobs/463813'},
#  {'title': 'Senior Data Engineer - Machine Learning Platform - ML Ops, Python, AWS',
#   'company': 'Socure',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/465269'},
#  {'title': '(Senior) Python Engineer (m/f/d) - Search & Ride Experience',
#   'company': 'TIER Mobility GmbH',
#   'location': 'Berlin, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/461175'},
#  {'title': 'Senior Python Dev for Open Source Dev Tools',
#   'company': 'Iterative, Inc',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/446359'},
#  {'title': 'Python/C++ DevOps Engineer',
#   'company': 'ADLARES GmbH',
#   'location': 'Teltow, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/441796'},
#  {'title': 'Python Engineer',
#   'company': 'Market America / Shop.com',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/431385'},
#  {'title': 'Cloud Infrastructure Lead  / AWS / Python / Ansible',
#   'company': 'ABOUT YOU GmbH',
#   'location': 'Hamburg, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/313508'},
#  {'title': 'Outreach Officer (Python, Perl or R)',
#   'company': 'European Bioinformatics Institute (EMBL-EBI)',
#   'location': 'Hinxton, UK',
#   'link': 'https://stackoverflow.com/jobs/454738'},
#  {'title': 'Technical Support Engineer (Java, Python)',
#   'company': 'DOCOMO Digital',
#   'location': 'Madrid, Spain',
#   'link': 'https://stackoverflow.com/jobs/451416'},
#  {'title': 'Senior Python Developer - Quick Commerce (f/m/d)',
#   'company': 'Delivery Hero SE',
#   'location': 'Berlin, Germany',
#   'link': 'https://stackoverflow.com/jobs/450784'},
#  {'title': 'Sr. Java or Python Full Stack Developer (5+ years, Calgary)',
#   'company': 'Blackline Safety',
#   'location': 'Calgary, AB, Canada',
#   'link': 'https://stackoverflow.com/jobs/443240'},
#  {'title': 'Full Stack Developer -Python Ruby on Rails AWS',
#   'company': 'HaysviaHays PLC',
#   'location': 'Toronto, ON, Canada',
#   'link': 'https://stackoverflow.com/jobs/426945'},
#  {'title': 'Cryptography/Cryptographic Engineer - C, C++, Matlab & Python',
#   'company': 'AngokaviaHays PLC',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/424548'},
#  {'title': 'Senior Machine Learning Engineer (w/m/d) | Python, Scala | Team Search',
#   'company': 'Otto (GmbH & Co KG)',
#   'location': 'Hamburg, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/461378'},
#  {'title': 'Principal Python Blockchain Developer - Raiden Network',
#   'company': 'brainbot',
#   'location': 'Berlin, Germany',
#   'link': 'https://stackoverflow.com/jobs/198297'},
#  {'title': 'Senior Snowflake BI Developer - SQL, SSAS, Tableau, Python & R (Senior, Remote)',
#   'company': 'TopDevz',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/467798'},
#  {'title': 'Mobile DevOps Engineer ( CI/CD, Jenkins, Ansible, AWS, Python)',
#   'company': 'buildit',
#   'location': 'Kraków, Poland',
#   'link': 'https://stackoverflow.com/jobs/427678'},
#  {'title': 'Sr. Engineer - Python Dev (Remote)',
#   'company': 'CrowdStrike, Inc.',
#   'location': 'Bucharest, Romania',
#   'link': 'https://stackoverflow.com/jobs/437549'},
#  {'title': '(Senior) Python Data Engineer - Marketing Tech (f/m/d)',
#   'company': 'Delivery Hero SE',
#   'location': 'Berlin, Germany',
#   'link': 'https://stackoverflow.com/jobs/452393'},
#  {'title': 'Architect and Hands-On Developer (Python/Java)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'link': 'https://stackoverflow.com/jobs/463856'},
#  {'title': 'Senior Data Engineer – ETL Pipelines - Python - Cybersecurity',
#   'company': 'Praetorian CybersecurityviaUplink Software Solutions',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/421770'},
#  {'title': 'Principal Cloud & DevOps Consultant (AWS, Python, DevOps)',
#   'company': 'Sourced Group Inc.',
#   'location': 'Singapore',
#   'link': 'https://stackoverflow.com/jobs/372723'},
#  {'title': '(Senior or Lead) Python Engineer (m/f/d) - Payments & Customer Loyalty',
#   'company': 'TIER Mobility GmbH',
#   'location': 'Berlin, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/461168'},
#  {'title': 'Enthusiastic developers for small informal software company',
#   'company': 'Black Cow Technology',
#   'location': 'Oxford, UK',
#   'link': 'https://stackoverflow.com/jobs/119562'},
#  {'title': 'Backend Developer PHP (m/w/d) in Leipzig, Halle (Saale) oder Dresden',
#   'company': 'Relaxdays GmbH',
#   'location': 'Leipzig, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/433896'},
#  {'title': 'Senior Node.js Engineer (m/f/d)',
#   'company': 'Fashion Cloud',
#   'location': 'Amsterdam, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/465988'},
#  {'title': 'Node.js Engineer (m/f/d)',
#   'company': 'Fashion Cloud',
#   'location': 'Amsterdam, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/460037'},
#  {'title': 'Senior Software Engineer - Frontend/Fullstack',
#   'company': 'Rollbar',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/454577'},
#  {'title': 'Frontend Developer (m/w/d) in Leipzig, Halle (Saale) oder Dresden',
#   'company': 'Relaxdays GmbH',
#   'location': 'Leipzig, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/433898'},
#  {'title': 'Backend Developer C# (w/m/d) in Leipzig, Halle (Saale) oder Dresden',
#   'company': 'Relaxdays GmbH',
#   'location': 'Leipzig, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/433895'},
#  {'title': 'Software Engineer in Test II/III',
#   'company': 'ArcherDX, Inc.',
#   'location': 'Boulder, CO',
#   'link': 'https://stackoverflow.com/jobs/460168'},
#  {'title': 'Lead Cloud Infrastructure Engineer',
#   'company': 'Tails.com',
#   'location': 'Richmond, UK',
#   'link': 'https://stackoverflow.com/jobs/466404'},
#  {'title': 'Software Engineer II/III',
#   'company': 'ArcherDX, Inc.',
#   'location': 'Boulder, CO',
#   'link': 'https://stackoverflow.com/jobs/460171'},
#  {'title': 'DevOps Engineer',
#   'company': 'ArcherDX, Inc.',
#   'location': 'Boulder, CO',
#   'link': 'https://stackoverflow.com/jobs/460170'},
#  {'title': 'Senior Growth Engineer',
#   'company': 'Rollbar',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/465826'},
#  {'title': 'Software Engineer - Clearance Required - Multidisciplinary',
#   'company': 'BrainGu',
#   'location': 'Chantilly, VA',
#   'link': 'https://stackoverflow.com/jobs/267449'},
#  {'title': 'Backend Software Developer',
#   'company': 'xe.gr (Xrysi Eukairia)',
#   'location': 'Athina, Greece',
#   'link': 'https://stackoverflow.com/jobs/456749'},
#  {'title': 'Backend developer',
#   'company': 'VIKTOR',
#   'location': 'Rotterdam, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/472215'},
#  {'title': 'Senior Software Engineer C++, Automotive (Ref. 2019-S-03)',
#   'company': 'Philotech Group',
#   'location': 'Getafe, Spanien',
#   'link': 'https://stackoverflow.com/jobs/351316'},
#  {'title': 'Frontend Developer',
#   'company': 'Government Digital Service (GDS)',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/457677'},
#  {'title': 'Backend Software Engineer',
#   'company': 'iptiQ by Swiss Re',
#   'location': 'Hoofddorp, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/472052'},
#  {'title': 'Backend Software Developer',
#   'company': 'xe.gr (Xrysi Eukairia)',
#   'location': 'Athina, Greece',
#   'link': 'https://stackoverflow.com/jobs/456749'},
#  {'title': 'Software Engineer - Go/ PostgreSQL',
#   'company': 'Apple',
#   'location': 'Shanghai, China',
#   'link': 'https://stackoverflow.com/jobs/471527'},
#  {'title': 'Gruppenleiter Software Engineering (m/w/d) – Automotive (Ref.Nr.:(2020-106)',
#   'company': 'Philotech Group',
#   'location': 'Taufkirchen, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/397507'},
#  {'title': 'Software Engineer - Corporate Technology | Risk & Forecasting Services',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Lewisville, TX',
#   'link': 'https://stackoverflow.com/jobs/465904'},
#  {'title': 'Architecte Infrastructure Cloud AWS',
#   'company': 'ENGIE Digital',
#   'location': 'Paris, France',
#   'link': 'https://stackoverflow.com/jobs/465127'},
#  {'title': 'Lead Software Engineer - Join our growing team of 30+ software engineers',
#   'company': 'Tails.com',
#   'location': 'Richmond, UK',
#   'link': 'https://stackoverflow.com/jobs/391983'},
#  {'title': 'Backend Developer',
#   'company': 'Octopus Energy',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/197943'},
#  {'title': 'Software Engineer - Backend',
#   'company': 'Hyper Labs, Inc., dba Hyperscience',
#   'location': 'Sofia, Bulgaria',
#   'link': 'https://stackoverflow.com/jobs/401117'},
#  {'title': 'Senior Backend Engineer',
#   'company': 'Penn Interactive Ventures',
#   'location': 'Philadelphia, PA',
#   'link': 'https://stackoverflow.com/jobs/472047'},
#  {'title': 'Full Stack Software Engineer',
#   'company': 'kaliber.ai',
#   'location': 'San Francisco, CA',
#   'link': 'https://stackoverflow.com/jobs/251476'},
#  {'title': 'Web developer',
#   'company': 'xe.gr (Xrysi Eukairia)',
#   'location': 'Athina, Greece',
#   'link': 'https://stackoverflow.com/jobs/447191'},
#  {'title': 'Software Engineer - Fullstack - remote (m/f/d)',
#   'company': 'Yelp',
#   'location': 'Hamburg, Germany',
#   'link': 'https://stackoverflow.com/jobs/463138'},
#  {'title': 'Software Engineering Manager',
#   'company': 'Hyperscience',
#   'location': 'Sofia, Bulgaria',
#   'link': 'https://stackoverflow.com/jobs/466425'},
#  {'title': 'Senior Sales Engineer (sales position)',
#   'company': 'OpenCraft',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/470815'},
#  {'title': 'Backend Software Engineer',
#   'company': 'Armored Things',
#   'location': 'Boston, MA',
#   'link': 'https://stackoverflow.com/jobs/322319'},
#  {'title': 'React Software Developer',
#   'company': 'Cluby',
#   'location': 'Helsinki, Finland',
#   'link': 'https://stackoverflow.com/jobs/469377'},
#  {'title': 'Principal Engineer for DRIVR (m/f/d) - English and German required',
#   'company': 'XCNT GmbH',
#   'location': 'Berlin, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/454977'},
#  {'title': 'IS&T Software Engineer',
#   'company': 'Apple',
#   'location': 'Shanghai, China',
#   'link': 'https://stackoverflow.com/jobs/463926'},
#  {'title': 'Senior Backend Engineer',
#   'company': 'AptEdge.io',
#   'location': 'San Mateo, CA',
#   'link': 'https://stackoverflow.com/jobs/457415'},
#  {'title': 'Software Engineer (m/f/d) for our Vehicle Supply Optimization team',
#   'company': 'MOIA GmbH',
#   'location': 'Hamburg, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/465025'},
#  {'title': 'Senior Backend Software Engineer',
#   'company': 'Cambly',
#   'location': 'San Francisco, CA',
#   'link': 'https://stackoverflow.com/jobs/459158'},
#  {'title': 'Full Stack Software Developer (remote - EU)',
#   'company': 'Optimile',
#   'location': 'Ghent, Belgium',
#   'link': 'https://stackoverflow.com/jobs/461393'},
#  {'title': 'Senior Backend Engineer (Remote or NYC)',
#   'company': 'Noom',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/283527'},
#  {'title': 'Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bournemouth, UK',
#   'link': 'https://stackoverflow.com/jobs/466348'},
#  {'title': 'Senior Sales Engineer (sales position)',
#   'company': 'OpenCraft',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/470815'},
#  {'title': 'Backend Software Engineer',
#   'company': 'Armored Things',
#   'location': 'Boston, MA',
#   'link': 'https://stackoverflow.com/jobs/322319'},
#  {'title': 'Software Engineer - Frontend - remote (m/f/d)',
#   'company': 'Yelp',
#   'location': 'Hamburg, Germany',
#   'link': 'https://stackoverflow.com/jobs/463434'},
#  {'title': 'Full Stack Developer',
#   'company': 'Mullvad VPN',
#   'location': 'Gothenburg, Sweden',
#   'link': 'https://stackoverflow.com/jobs/448302'},
#  {'title': 'Research Software Engineer',
#   'company': 'Technical University of DenmarkviaDTU - Technical University of Denmark',
#   'location': 'Copenhagen, Denmark',
#   'link': 'https://stackoverflow.com/jobs/468723'},
#  {'title': 'Backend Software Engineer (80-100%)',
#   'company': 'iptiQ by Swiss Re',
#   'location': 'Zürich, Switzerland',
#   'link': 'https://stackoverflow.com/jobs/471197'},
#  {'title': 'Senior Backend Software Engineer - Edge Computing',
#   'company': 'Prescriptive Data LLC',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/431815'},
#  {'title': 'Principal Engineer for DRIVR (m/f/d) - English and German required',
#   'company': 'XCNT GmbH',
#   'location': 'Berlin, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/454977'},
#  {'title': 'Software Engineering Manager',
#   'company': 'iptiQ by Swiss Re',
#   'location': 'Hoofddorp, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/472051'},
#  {'title': 'IS&T Software Engineer',
#   'company': 'Apple',
#   'location': 'Shanghai, China',
#   'link': 'https://stackoverflow.com/jobs/463926'},
#  {'title': 'Staff Software Engineer, Data/Systems',
#   'company': 'Oscar Health',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/458440'},
#  {'title': 'Senior Backend Engineer',
#   'company': 'AptEdge.io',
#   'location': 'San Mateo, CA',
#   'link': 'https://stackoverflow.com/jobs/457415'},
#  {'title': 'Senior Full Stack Developer (m/f/d) - WANTED',
#   'company': 'FIFTY2 Technology GmbH',
#   'location': 'Freiburg im Breisgau, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/439694'},
#  {'title': 'REMOTE Germany-wide - Data Engineer (f/m/d)',
#   'company': 'real.digital',
#   'location': 'Köln, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/456776'},
#  {'title': 'Software Engineer (m/f/d) for our Vehicle Supply Optimization team',
#   'company': 'MOIA GmbH',
#   'location': 'Hamburg, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/465025'},
#  {'title': 'Fullstack Web Developer',
#   'company': 'Smart Energy Lab',
#   'location': 'Lisbon, Portugal',
#   'link': 'https://stackoverflow.com/jobs/465125'},
#  {'title': 'Lead Software Engineer (CRM & Business APIs) (m/f/d)',
#   'company': 'LABSTER AGviaHays PLC',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/452354'},
#  {'title': 'Senior Backend Developer (f/m/d) at the leading provider of data rooms in Europe',
#   'company': 'Drooms GmbH',
#   'location': 'Frankfurt am Main, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/372347'},
#  {'title': 'Senior Backend Engineer (Remote or NYC)',
#   'company': 'Noom',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/283527'},
#  {'title': 'Software Developer C++ for 3D maps - remote',
#   'company': 'Atlatec GmbH',
#   'location': 'Kiew, Ukraine',
#   'link': 'https://stackoverflow.com/jobs/341653'},
#  {'title': 'Technical Lead in Software Engineering',
#   'company': 'UCARE.AI',
#   'location': 'Singapore',
#   'link': 'https://stackoverflow.com/jobs/443246'},
#  {'title': 'Intermediate Full Stack Developer (m/f/d) in Freiburg/Breisgau',
#   'company': 'FIFTY2 Technology GmbH',
#   'location': 'Freiburg im Breisgau, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/459590'},
#  {'title': 'Web Application Developer',
#   'company': 'RSR Group',
#   'location': 'Winter Park, FL',
#   'link': 'https://stackoverflow.com/jobs/424542'},
#  {'title': "Django Engineer (m/f) for Germany's leading local marketing platform",
#   'company': 'RegioHelden GmbH',
#   'location': 'Stuttgart, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/420093'},
#  {'title': 'Software Engineering',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/469804'},
#  {'title': 'Technical Lead in Software Engineering',
#   'company': 'UCARE.AI',
#   'location': 'Singapore',
#   'link': 'https://stackoverflow.com/jobs/443246'},
# ...
#   'company': 'SemanticBits',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/366169'},
#  {'title': 'DevOps engineer',
#   'company': 'Singular AG',
#   'location': 'Zürich, Switzerland',
#   'link': 'https://stackoverflow.com/jobs/447902'},
#  {'title': 'Applications Support Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'link': 'https://stackoverflow.com/jobs/467976'},
#  {'title': 'Senior Full Stack Engineer interested in collaborative hardware development',
#   'company': 'Wikifactory',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/386765'},
#  {'title': 'Backend Engineer, Cloud Platform',
#   'company': 'Oura Health Oy',
#   'location': 'Helsinki, Finland',
#   'link': 'https://stackoverflow.com/jobs/462179'},
#  {'title': 'QA Automation Engineer - Russia (Remote)',
#   'company': 'Agiloft',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/445471'},
#  {'title': 'Casino Games Tech Lead',
#   'company': 'DraftKings',
#   'location': 'Sofia, Bulgaria',
#   'link': 'https://stackoverflow.com/jobs/416811'},
#  {'title': 'Java Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'link': 'https://stackoverflow.com/jobs/460492'},
#  {'title': 'Applications Support',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Mumbai, India',
#   'link': 'https://stackoverflow.com/jobs/468994'},
#  {'title': 'Engineering Manager - Infrastructure',
#   'company': 'Yelp',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/282014'},
#  {'title': 'Back End Developer, Go, (M/F/X), AI team, Frankfurt',
#   'company': 'EVANA AG',
#   'location': 'Frankfurt, Germany',
#   'link': 'https://stackoverflow.com/jobs/453424'},
#  {'title': 'Mobile Robotics Engineer',
#   'company': 'Ocado Technology',
#   'location': 'Hatfield, UK',
#   'link': 'https://stackoverflow.com/jobs/468975'},
#  {'title': 'Principal Data Scientist',
#   'company': 'Citizens Bank',
#   'location': 'Providence, RI',
#   'link': 'https://stackoverflow.com/jobs/472061'},
#  {'title': 'Dev Ops Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/470340'},
#  {'title': 'Dev ops Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/470339'},
#  {'title': 'Site Reliability Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Mumbai, India',
#   'link': 'https://stackoverflow.com/jobs/469591'},
#  {'title': 'Algo Internship - Summer 2021',
#   'company': 'Hudson River Trading',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/433582'},
#  {'title': 'Infrastructure Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/471672'},
#  {'title': 'Fullstack Developer',
#   'company': 'Engineering Solutions, Inc.',
#   'location': 'Hanover, MD',
#   'link': 'https://stackoverflow.com/jobs/390195'},
#  {'title': 'Staff Software Engineer, Infrastructure, Education',
#   'company': 'Chan Zuckerberg Initiative',
#   'location': 'Redwood City, CA',
#   'link': 'https://stackoverflow.com/jobs/446365'},
#  {'title': 'Junior Signal Processing Engineer',
#   'company': 'Tatch',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/423567'},
#  {'title': 'CoreOS Triage Engineer',
#   'company': 'Apple',
#   'location': 'Shanghai, China',
#   'link': 'https://stackoverflow.com/jobs/409190'},
#  {'title': 'Cloud Platform Engineer',
#   'company': 'UKG (Ultimate Kronos Group)',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/471581'},
#  {'title': 'Vice President of Engineering',
#   'company': 'Octane AI',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/457942'},
#  {'title': 'Senior Data Platform Engineer',
#   'company': 'IHS Markit',
#   'location': 'Englewood, CO',
#   'link': 'https://stackoverflow.com/jobs/468510'},
#  {'title': 'Software Architects (Multiple Locations)',
#   'company': 'Salesforce',
#   'location': 'Seattle, WA',
#   'link': 'https://stackoverflow.com/jobs/364250'},
#  {'title': 'Software Engineer Principal',
#   'company': 'The Home Depot',
#   'location': 'Atlanta, GA',
#   'link': 'https://stackoverflow.com/jobs/425125'},
#  {'title': 'Senior Site Reliability Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'link': 'https://stackoverflow.com/jobs/470512'},
#  {'title': 'Quality Automation Engineer',
#   'company': 'F-Secure',
#   'location': 'Helsinki, Finland',
#   'link': 'https://stackoverflow.com/jobs/445058'},
#  {'title': 'Data Engineer | Geospatial / CloudOps',
#   'company': 'Colaberry',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/471180'},
#  {'title': '(Senior-) Softwareentwickler (m/w/d) Embedded DSP',
#   'company': 'Müller-BBM Active Sound Technology GmbH',
#   'location': 'Planegg, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/460960'},
#  {'title': 'Security & Compliance Automation Developer',
#   'company': 'Apple',
#   'location': 'Sacramento, CA',
#   'link': 'https://stackoverflow.com/jobs/469350'},
#  {'title': 'Software Development Engineer (ALL LEVELS) - Distributed Systems Security',
#   'company': 'Salesforce',
#   'location': 'Bellevue, WA',
#   'link': 'https://stackoverflow.com/jobs/364144'},
#  {'title': 'Build Service Engineer',
#   'company': 'SUSE',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/471547'},
#  {'title': 'Goang Developer',
#   'company': 'Get GroundviaEurostaff Group GmbH',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/456517'},
#  {'title': 'Production Support (DevOps) : Data Analytics - Associate',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Singapore',
#   'link': 'https://stackoverflow.com/jobs/468141'},
#  {'title': 'Casino Games Tech Lead',
#   'company': 'DraftKings',
#   'location': 'Sofia, Bulgaria',
#   'link': 'https://stackoverflow.com/jobs/416811'},
#  {'title': 'Opex Technical Support Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Chicago, IL',
#   'link': 'https://stackoverflow.com/jobs/467299'},
#  {'title': 'Senior Full Stack Engineer (w/m/d) Java/GCP | Inbound Logistik',
#   'company': 'Otto (GmbH & Co KG)',
#   'location': 'Hamburg, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/462188'},
#  {'title': 'Back End Developer, Go, (M/F/X), AI team, Frankfurt',
#   'company': 'EVANA AG',
#   'location': 'Frankfurt, Germany',
#   'link': 'https://stackoverflow.com/jobs/453424'},
#  {'title': 'Senior Systems Administrator (Washington, D.C. or U.S. Remote)',
#   'company': 'Wallethub',
#   'location': 'Washington, DC',
#   'link': 'https://stackoverflow.com/jobs/469541'},
#  {'title': 'Cognos Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'link': 'https://stackoverflow.com/jobs/464024'},
#  {'title': 'Site Reliability Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Mumbai, India',
#   'link': 'https://stackoverflow.com/jobs/469591'},
#  {'title': 'Softwareentwickler* C/C++ autonomes Fahren',
#   'company': 'EDAG Group',
#   'location': 'Ingolstadt, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/459584'},
#  {'title': 'Cloud Solutions Engineer - Apple Cloud Technologies',
#   'company': 'Apple',
#   'location': 'Austin, TX',
#   'link': 'https://stackoverflow.com/jobs/465672'},
#  {'title': 'Machine Learning Engineer',
#   'company': 'Olive',
#   'location': 'Columbus, OH',
#   'link': 'https://stackoverflow.com/jobs/462270'},
#  {'title': 'Site Reliability Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Newark, DE',
#   'link': 'https://stackoverflow.com/jobs/471474'},
#  {'title': 'Dev Ops Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/470342'},
#  {'title': 'Senior Front End Developer',
#   'company': 'BOTS by RevenYOU',
#   'location': 'Haarlem, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/432956'},
#  {'title': 'Full Stack Developer',
#   'company': 'SMAL Code GmbH',
#   'location': 'Munich, Germany',
#   'link': 'https://stackoverflow.com/jobs/415645'},
#  {'title': 'C++ Developer',
#   'company': 'Optiver Asia Pacific Pty Ltd',
#   'location': 'Sydney, Australia',
#   'link': 'https://stackoverflow.com/jobs/411345'},
#  {'title': 'Infrastructure Engineering',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/468294'},
#  {'title': 'Softwareentwickler eMobility und IoT',
#   'company': 'beegy GmbH',
#   'location': 'Mannheim, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/462267'},
#  {'title': 'Software Engineer Principal',
#   'company': 'The Home Depot',
#   'location': 'Atlanta, GA',
#   'link': 'https://stackoverflow.com/jobs/425125'},
#  {'title': 'Team Lead Engineering',
#   'company': 'FiscalNote',
#   'location': 'Washington, DC',
#   'link': 'https://stackoverflow.com/jobs/455946'},
#  {'title': '[100% REMOTE] Sr. Snowflake Data Engineer',
#   'company': 'Clevertech',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/470793'},
#  {'title': 'Senior Enterprise Detection Blueprint Engineer',
#   'company': 'SAP',
#   'location': 'Newtown Square, PA',
#   'link': 'https://stackoverflow.com/jobs/450395'},
#  {'title': 'DevOps / SRE (Americas)',
#   'company': 'Platform.sh',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/463351'},
#  {'title': 'Senior Site Reliability Engineer',
#   'company': 'OpenMarket',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/441544'},
#  {'title': 'Audio-AI SW Engineer',
#   'company': 'Gaudio Lab',
#   'location': 'Yeoksam-dong, South Korea',
#   'link': 'https://stackoverflow.com/jobs/435216'},
#  {'title': 'Java Wholesale Payments Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Glasgow, UK',
#   'link': 'https://stackoverflow.com/jobs/461214'},
#  {'title': 'IT Consultant',
#   'company': 'Reply',
#   'location': 'Milan, Italy',
#   'link': 'https://stackoverflow.com/jobs/461389'},
#  {'title': 'Product Manager SIEM Platform',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Wilmington, DE',
#   'link': 'https://stackoverflow.com/jobs/469574'},
#  {'title': 'Data Engineer',
#   'company': 'BTI360',
#   'location': 'Ashburn, VA',
#   'link': 'https://stackoverflow.com/jobs/410141'},
#  {'title': 'Goang Developer',
#   'company': 'Get GroundviaEurostaff Group GmbH',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/456517'},
#  {'title': 'Production Support (DevOps) : Data Analytics - Associate',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Singapore',
#   'link': 'https://stackoverflow.com/jobs/468141'},
#  {'title': 'Data Engineer - Metrics [Remote]',
#   'company': 'TMP Worldwide',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/459807'},
#  {'title': 'Opex Technical Support Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Chicago, IL',
#   'link': 'https://stackoverflow.com/jobs/467299'},
#  {'title': 'Senior Systems Administrator (Washington, D.C. or U.S. Remote)',
#   'company': 'Wallethub',
#   'location': 'Washington, DC',
#   'link': 'https://stackoverflow.com/jobs/469541'},
#  {'title': 'Hacker – Spezialist für CNE-Operationen (m/w/d)',
#   'company': 'Bundesnachrichtendienst',
#   'location': 'Berlin, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/465967'},
#  {'title': 'Softwareentwicklung und Projektleitung für operationelle Satellitenbodensysteme',
#   'company': 'Deutsches Zentrum für Luft- und Raumfahrt e.V.',
#   'location': 'Weßling, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/460645'},
#  {'title': 'Software Engineer - SDVI DevOps',
#   'company': 'SDVI',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/451626'},
#  {'title': 'Site Reliability Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Lewisville, TX',
#   'link': 'https://stackoverflow.com/jobs/471409'},
#  {'title': 'Senior Software Engineer - Standard Data Feeds',
#   'company': 'FactSet',
#   'location': 'Norwalk, CT',
#   'link': 'https://stackoverflow.com/jobs/460258'},
#  {'title': 'Site Reliability Engineer - CI/CD',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Columbus, OH',
#   'link': 'https://stackoverflow.com/jobs/464433'},
#  {'title': 'Build Service Engineer',
#   'company': 'SUSE',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/471547'},
#  {'title': 'Azure Cloud Developer',
#   'company': 'Acolyte Group',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/451928'},
#  {'title': 'Data Scientist',
#   'company': 'Hays Specialist RecruitmentviaHays PLC',
#   'location': 'Adelaide, Australia',
#   'link': 'https://stackoverflow.com/jobs/451663'},
#  {'title': 'Senior Wireless Data Network Engineer - Infrastructure Engineering',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Columbus, OH',
#   'link': 'https://stackoverflow.com/jobs/471671'},
#  {'title': 'Senior Full Stack Engineer (w/m/d) Java/GCP | Inbound Logistik',
#   'company': 'Otto (GmbH & Co KG)',
#   'location': 'Hamburg, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/462188'},
#  {'title': 'Data Engineer',
#   'company': 'Trax Retail Ltd',
#   'location': 'Budapest, Hungary',
#   'link': 'https://stackoverflow.com/jobs/450794'},
#  {'title': 'Technical Product Support Engineer (Remote)',
#   'company': 'Olive AI',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/410488'},
#  {'title': 'Asset Management- Highbridge- Risk Associate',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/463506'},
#  {'title': 'Cloud Solutions Engineer - Apple Cloud Technologies',
#   'company': 'Apple',
#   'location': 'Austin, TX',
#   'link': 'https://stackoverflow.com/jobs/465672'},
#  {'title': 'Scientific Applications Developer',
#   'company': 'DownUnder GeoSolutions Pty Ltd',
#   'location': 'West Perth, Australia',
#   'link': 'https://stackoverflow.com/jobs/396026'},
#  {'title': 'Mid-level Data Scientist',
#   'company': 'Envelop Risk',
#   'location': 'Bristol, UK',
#   'link': 'https://stackoverflow.com/jobs/364981'},
#  {'title': 'QA Automation Engineer - Russia (Remote)',
#   'company': 'Agiloft',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/445471'},
#  {'title': 'Senior / Lead Product Analyst',
#   'company': 'Blinkist',
#   'location': 'Berlin, Germany',
#   'link': 'https://stackoverflow.com/jobs/465262'},
#  {'title': 'Java Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'link': 'https://stackoverflow.com/jobs/460492'},
#  {'title': 'Principal Data Scientist',
#   'company': 'Citizens Bank',
#   'location': 'Providence, RI',
#   'link': 'https://stackoverflow.com/jobs/472061'},
#  {'title': 'Developer / Bioinformatician',
#   'company': 'European Bioinformatics Institute (EMBL-EBI)',
#   'location': 'Hinxton, UK',
#   'link': 'https://stackoverflow.com/jobs/455801'},
#  {'title': 'Fullstack Developer',
#   'company': 'Engineering Solutions, Inc.',
#   'location': 'Hanover, MD',
#   'link': 'https://stackoverflow.com/jobs/390195'},
#  {'title': 'Infrastructure Development',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/471253'},
#  {'title': 'Senior Data Engineer',
#   'company': 'StyleSeat',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/462924'},
#  {'title': 'Software Engineer - Currencies and Emerging Markets, Associate',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Singapore',
#   'link': 'https://stackoverflow.com/jobs/470569'},
#  {'title': 'Data Engineer (m/w/d) nationwide',
#   'company': "Bayerischer Rundfunk'",
#   'location': 'Munich, Germany',
#   'link': 'https://stackoverflow.com/jobs/468272'},
#  ...]

# %%
len(jobs)
# Out:
# 3134

# %% [markdown]
# ##  csv파일 형식으로 저장

# %%
from save import save_to_file

# %%
save_to_file(jobs)

# %% [markdown]
# ## 데이터 프레임으로 출력

# %%
import pandas as pd
df = pd.read_csv("jobs.csv")

# %%
df
# Out:
#                                          title                      company  \
# 0                     Python Software Engineer                      bloomon
# 1      Senior Backend Engineer (Python/Django)                      NewtonX
# 2      Remote Senior Software Engineer, Python                        Verys
# 3            Senior Software Engineer (Python)                    HealthJoy
# 4                         Python Web Developer  RavenPack International SL.
# ...                                        ...                          ...
# 3129                              cloud/saas개발                Success Korea
# 3130  Senior Business Analysis (CRM Targeting)                      Coupang
# 3131                   DevOps Developer(Cloud)                Success Korea
# 3132                                플랫폼 백엔드 개발                Success Korea
# 3133  Microsoft Azure Cloud Solution Architect                Success Korea
#
#                     location  \
# 0     Amsterdam, Netherlands
# 1               New York, NY
# 2              Santa Ana, CA
# 3              Kyiv, Ukraine
# 4            Marbella, Spain
# ...                      ...
# 3129                      서울
# 3130                      서울
# 3131                  서울 논현동
# 3132                      서울
# 3133                  서울 논현동
#
#                                                    link
# 0                 https://stackoverflow.com/jobs/286140
# 1                 https://stackoverflow.com/jobs/470973
# 2                 https://stackoverflow.com/jobs/469797
# 3                 https://stackoverflow.com/jobs/457700
# 4                 https://stackoverflow.com/jobs/470988
# ...                                                 ...
# 3129  https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3...
# 3130  https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3...
# 3131  https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3...
# 3132  https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3...
# 3133  https://kr.indeed.com/%EC%B1%84%EC%9A%A9%EB%B3...
#
# [3134 rows x 4 columns]
